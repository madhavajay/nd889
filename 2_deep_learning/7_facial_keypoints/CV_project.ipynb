# %% [markdown]
# # Artificial Intelligence Nanodegree
# ## Computer Vision Capstone
# ## Project: Facial Keypoint Detection
#
# ---
#
# Welcome to the final Computer Vision project in the Artificial Intelligence Nanodegree program!
#
# In this project, you’ll combine your knowledge of computer vision techniques and deep learning to build and end-to-end facial keypoint recognition system! Facial keypoints include points around the eyes, nose, and mouth on any face and are used in many applications, from facial tracking to emotion recognition.
#
# There are three main parts to this project:
#
# **Part 1** : Investigating OpenCV, pre-processing, and face detection
#
# **Part 2** : Training a Convolutional Neural Network (CNN) to detect facial keypoints
#
# **Part 3** : Putting parts 1 and 2 together to identify facial keypoints on any image!
#
# ---
#
# **Here's what you need to know to complete the project:*
#
# 1. In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested.
#
#     a. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
#
# 2. In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation.
#
#     a. Each section where you will answer a question is preceded by a **'Question X'** header.
#
#     b. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains **optional** suggestions for enhancing the project beyond the minimum requirements. If you decide to pursue the "(Optional)" sections, you should include the code in this IPython notebook.
#
# Your project submission will be evaluated based on your answers to *each* of the questions and the code implementations you provide.

# %% [markdown]
# ### Steps to Complete the Project
#
# Each part of the notebook is further broken down into separate steps.  Feel free to use the links below to navigate the notebook.
#
# In this project you will get to explore a few of the many computer vision algorithms built into the OpenCV library.  This expansive computer vision library is now [almost 20 years old](https://en.wikipedia.org/wiki/OpenCV#History) and still growing!
#
# The project itself is broken down into three large parts, then even further into separate steps.  Make sure to read through each step, and complete any sections that begin with **'(IMPLEMENTATION)'** in the header; these implementation sections may contain multiple TODOs that will be marked in code.  For convenience, we provide links to each of these steps below.
#
# **Part 1** : Investigating OpenCV, pre-processing, and face detection
#
# * [Step 0](#step0): Detect Faces Using a Haar Cascade Classifier
# * [Step 1](#step1): Add Eye Detection
# * [Step 2](#step2): De-noise an Image for Better Face Detection
# * [Step 3](#step3): Blur an Image and Perform Edge Detection
# * [Step 4](#step4): Automatically Hide the Identity of an Individual
#
# **Part 2** : Training a Convolutional Neural Network (CNN) to detect facial keypoints
#
# * [Step 5](#step5): Create a CNN to Recognize Facial Keypoints
# * [Step 6](#step6): Compile and Train the Model
# * [Step 7](#step7): Visualize the Loss and Answer Questions
#
# **Part 3** : Putting parts 1 and 2 together to identify facial keypoints on any image!
#
# * [Step 8](#step7): Build a Robust Facial Keypoints Detector (Complete the CV Pipeline)

# %% [markdown]
# ---
# <a id='step0'></a>
# ## Step 0: Detect Faces Using a Haar Cascade Classifier
#
# Have you ever wondered how Facebook automatically tags images with your friends' faces?   Or how high-end cameras automatically find and focus on a certain person's face?  Applications like these depend heavily on the machine learning task known as *face detection* -  which is the task of automatically finding faces in images containing people.
#
# At its root face detection is a classification problem - that is a problem of distinguishing between distinct classes of things.  With face detection these distinct classes are 1) images of human faces and 2) everything else.
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `detector_architectures` directory.

# %% [markdown]
# ### Import Resources
#
# In the next python cell, we load in the required libraries for this section of the project.

# %%
# Import required libraries for this section

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import math
import cv2                     # OpenCV library for computer vision
from PIL import Image
import time

# %% [markdown]
# Next, we load in and display a test image for performing face detection.
#
# *Note*: by default OpenCV assumes the ordering of our image's color channels are Blue, then Green, then Red.  This is slightly out of order with most image types we'll use in these experiments, whose color channels are ordered Red, then Green, then Blue.  In order to switch the Blue and Red channels of our test image around we will use OpenCV's ```cvtColor``` function, which you can read more about by [checking out some of its documentation located here](http://docs.opencv.org/3.2.0/df/d9d/tutorial_py_colorspaces.html).  This is a general utility function that can do other transformations too like converting a color image to grayscale, and transforming a standard color image to HSV color space.

# %%
# Load in color image for face detection
image = cv2.imread('images/test_image_1.jpg')

# Convert the image to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Plot our image using subplots to specify a size and title
fig = plt.figure(figsize = (8,8))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Original Image')
ax1.imshow(image)

# %% [markdown]
# There are a lot of people - and faces - in this picture.  13 faces to be exact!  In the next code cell, we demonstrate how to use a Haar Cascade classifier to detect all the faces in this test image.
#
# This face detector uses information about patterns of intensity in an image to reliably detect faces under varying light conditions. So, to use this face detector, we'll first convert the image from color to grayscale.
#
# Then, we load in the fully trained architecture of the face detector -- found in the file *haarcascade_frontalface_default.xml* - and use it on our image to find faces!
#
# To learn more about the parameters of the detector see [this post](https://stackoverflow.com/questions/20801015/recommended-values-for-opencv-detectmultiscale-parameters).

# %%
# Convert the RGB  image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Extract the pre-trained face detector from an xml file
face_cascade = cv2.CascadeClassifier('detector_architectures/haarcascade_frontalface_default.xml')

# Detect the faces in image
faces = face_cascade.detectMultiScale(gray, 4, 6)

# Print the number of faces detected in the image
print('Number of faces detected:', len(faces))

# Make a copy of the orginal image to draw face detections on
image_with_detections = np.copy(image)

# Get the bounding box for each detected face
for (x,y,w,h) in faces:
    # Add a red bounding box to the detections image
    cv2.rectangle(image_with_detections, (x,y), (x+w,y+h), (255,0,0), 3)
    

# Display the image with the detections
fig = plt.figure(figsize = (8,8))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Image with Face Detections')
ax1.imshow(image_with_detections)

# %% [markdown]
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.

# %% [markdown]
# ---
# <a id='step1'></a>
#
# ## Step 1: Add Eye Detections
#
# There are other pre-trained detectors available that use a Haar Cascade Classifier - including full human body detectors, license plate detectors, and more.  [A full list of the pre-trained architectures can be found here](https://github.com/opencv/opencv/tree/master/data/haarcascades).

# %% [markdown]
# To test your eye detector, we'll first read in a new test image with just a single face.

# %%
# Load in color image for face detection
image = cv2.imread('images/james.jpg')

# Convert the image to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Plot the RGB image
fig = plt.figure(figsize = (6,6))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Original Image')
ax1.imshow(image)

# %% [markdown]
# Notice that even though the image is a black and white image, we have read it in as a color image and so it will still need to be converted to grayscale in order to perform the most accurate face detection.
#
# So, the next steps will be to convert this image to grayscale, then load OpenCV's face detector and run it with parameters that detect this face accurately.

# %%
# Convert the RGB  image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Extract the pre-trained face detector from an xml file
face_cascade = cv2.CascadeClassifier('detector_architectures/haarcascade_frontalface_default.xml')

# Detect the faces in image
faces = face_cascade.detectMultiScale(gray, 1.25, 6)

# Print the number of faces detected in the image
print('Number of faces detected:', len(faces))

# Make a copy of the orginal image to draw face detections on
image_with_detections = np.copy(image)

# Get the bounding box for each detected face
for (x,y,w,h) in faces:
    # Add a red bounding box to the detections image
    cv2.rectangle(image_with_detections, (x,y), (x+w,y+h), (255,0,0), 3)
    

# Display the image with the detections
fig = plt.figure(figsize = (6,6))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Image with Face Detection')
ax1.imshow(image_with_detections)

# %% [markdown]
# ### (IMPLEMENTATION) Add an eye detector to the current face detection setup.
#
# A Haar-cascade eye detector can be included in the same way that the face detector was and, in this first task, it will be your job to do just this.

# %% [markdown]
# To set up an eye detector, use the stored parameters of the eye cascade detector, called ```haarcascade_eye.xml```, located in the `detector_architectures` subdirectory.  In the next code cell, create your eye detector and store its detections.
#
# **A few notes before you get started**:
#
# First, make sure to give your loaded eye detector the variable name
#
# ``eye_cascade``
#
#
# and give the list of eye regions you detect the variable name
#
# ``eyes``
#
# Second, since we've already run the face detector over this image, you should only search for eyes *within the rectangular face regions detected in ``faces``*.  This will minimize false detections.
#
# Lastly, once you've run your eye detector over the facial detection region, you should display the RGB image with both the face detection boxes (in red) and your eye detections (in green) to verify that everything works as expected.

# %%
# Make a copy of the original image to plot rectangle detections
image_with_detections = np.copy(image)   

# Loop over the detections and draw their corresponding face detection boxes
for (x,y,w,h) in faces:
    cv2.rectangle(image_with_detections, (x,y), (x+w,y+h),(255,0,0), 3)  
    
# Do not change the code above this comment!

    
## TODO: Add eye detection, using haarcascade_eye.xml, to the current face detector algorithm
## TODO: Loop over the eye detections and draw their corresponding boxes in green on image_with_detections


# Plot the image with both faces and eyes detected
fig = plt.figure(figsize = (6,6))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Image with Face and Eye Detection')
ax1.imshow(image_with_detections)

# %% [markdown]
# ## (Optional) Add face and eye detection to your laptop camera
#
# It's time to kick it up a notch, and add face and eye detection to your laptop's camera!  Afterwards, you'll be able to show off your creation like in the gif shown below - made with a completed version of the code!
#
# <img src="images/laptop_face_detector_example.gif" width=400 height=300/>
#
# Notice that not all of the detections here are perfect - and your result need not be perfect either.   You should spend a small amount of time tuning the parameters of your detectors to get reasonable results, but don't hold out for perfection.  If we wanted perfection we'd need to spend a ton of time tuning the parameters of each detector, cleaning up the input image frames, etc. You can think of this as more of a rapid prototype.
#
# The next cell contains code for a wrapper function called ``laptop_camera_face_eye_detector`` that, when called, will activate your laptop's camera.  You will place the relevant face and eye detection code in this wrapper function to implement face/eye detection and mark those detections on each image frame that your camera captures.
#
# Before adding anything to the function, you can run it to get an idea of how it works - a small window should pop up showing you the live feed from your camera; you can press any key to close this window.
#
# **Note:** Mac users may find that activating this function kills the kernel of their notebook every once in a while.  If this happens to you, just restart your notebook's kernel, activate cell(s) containing any crucial import statements, and you'll be good to go!

# %%
### Add face and eye detection to this laptop camera function 
# Make sure to draw out all faces/eyes found in each frame on the shown video feed

import cv2
import time 

# wrapper function for face/eye detection with your laptop camera
def laptop_camera_go():
    # Create instance of video capturer
    cv2.namedWindow("face detection activated")
    vc = cv2.VideoCapture(0)

    # Try to get the first frame
    if vc.isOpened(): 
        rval, frame = vc.read()
    else:
        rval = False
    
    # Keep the video stream open
    while rval:
        # Plot the image from camera with all the face and eye detections marked
        cv2.imshow("face detection activated", frame)
        
        # Exit functionality - press any key to exit laptop video
        key = cv2.waitKey(20)
        if key > 0: # Exit by pressing any key
            # Destroy windows 
            cv2.destroyAllWindows()
            
            # Make sure window closes on OSx
            for i in range (1,5):
                cv2.waitKey(1)
            return
        
        # Read next frame
        time.sleep(0.05)             # control framerate for computation - default 20 frames per sec
        rval, frame = vc.read()

# %%
# Call the laptop camera face/eye detector function above
laptop_camera_go()

# %% [markdown]
# ---
# <a id='step2'></a>
#
# ## Step 2: De-noise an Image for Better Face Detection

# %% [markdown]
# Image quality is an important aspect of any computer vision task. Typically, when creating a set of images to train a deep learning network, significant care is taken to ensure that training images are free of visual noise or artifacts that hinder object detection.  While computer vision algorithms - like a face detector - are typically trained on 'nice' data such as this, new test data doesn't always look so nice!
#
# When applying a trained computer vision algorithm to a new piece of test data one often cleans it up first before feeding it in.  This sort of cleaning - referred to as *pre-processing* - can include a number of cleaning phases like blurring, de-noising, color transformations, etc., and many of these tasks can be accomplished using OpenCV.
#
# In this short subsection we explore OpenCV's noise-removal functionality to see how we can clean up a noisy image, which we then feed into our trained face detector.

# %% [markdown]
# ### Create a noisy image to work with
#
# In the next cell, we create an artificial noisy version of the previous multi-face image.  This is a little exaggerated - we don't typically get images that are this noisy - but [image noise](https://digital-photography-school.com/how-to-avoid-and-reduce-noise-in-your-images/), or 'grainy-ness' in a digitial image - is a fairly common phenomenon.

# %%
# Load in the multi-face test image again
image = cv2.imread('images/test_image_1.jpg')

# Convert the image copy to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Make an array copy of this image
image_with_noise = np.asarray(image)

# Create noise - here we add noise sampled randomly from a Gaussian distribution: a common model for noise
noise_level = 40
noise = np.random.randn(image.shape[0],image.shape[1],image.shape[2])*noise_level

# Add this noise to the array image copy
image_with_noise = image_with_noise + noise

# Convert back to uint8 format
image_with_noise = np.asarray([np.uint8(np.clip(i,0,255)) for i in image_with_noise])

# Plot our noisy image!
fig = plt.figure(figsize = (8,8))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Noisy Image')
ax1.imshow(image_with_noise)

# %% [markdown]
# In the context of face detection, the problem with an image like this is that  - due to noise - we may miss some faces or get false detections.
#
# In the next cell we apply the same trained OpenCV detector with the same settings as before, to see what sort of detections we get.

# %%
# Convert the RGB  image to grayscale
gray_noise = cv2.cvtColor(image_with_noise, cv2.COLOR_RGB2GRAY)

# Extract the pre-trained face detector from an xml file
face_cascade = cv2.CascadeClassifier('detector_architectures/haarcascade_frontalface_default.xml')

# Detect the faces in image
faces = face_cascade.detectMultiScale(gray_noise, 4, 6)

# Print the number of faces detected in the image
print('Number of faces detected:', len(faces))

# Make a copy of the orginal image to draw face detections on
image_with_detections = np.copy(image_with_noise)

# Get the bounding box for each detected face
for (x,y,w,h) in faces:
    # Add a red bounding box to the detections image
    cv2.rectangle(image_with_detections, (x,y), (x+w,y+h), (255,0,0), 3)
    

# Display the image with the detections
fig = plt.figure(figsize = (8,8))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Noisy Image with Face Detections')
ax1.imshow(image_with_detections)

# %% [markdown]
# With this added noise we now miss one of the faces!

# %% [markdown]
# ### (IMPLEMENTATION) De-noise this image for better face detection
#
# Time to get your hands dirty: using OpenCV's built in color image de-noising functionality called ```fastNlMeansDenoisingColored``` - de-noise this image enough so that all the faces in the image are properly detected.  Once you have cleaned the image in the next cell, use the cell that follows to run our trained face detector over the cleaned image to check out its detections.
#
# You can find its [official documentation here]([documentation for denoising](http://docs.opencv.org/trunk/d1/d79/group__photo__denoise.html#ga21abc1c8b0e15f78cd3eff672cb6c476) and [a useful example here](http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_photo/py_non_local_means/py_non_local_means.html).
#
#
# **Note:** you can keep all parameters *except* `photo_render` fixed as shown in the second link above.  Play around with the value of this parameter - see how it affects the resulting cleaned image.

# %%
## TODO: Use OpenCV's built in color image de-noising function to clean up our noisy image!


denoised_image = # your final de-noised image (should be RGB)

# %%
## TODO: Run the face detector on the de-noised image to improve your detections and display the result

# %% [markdown]
# ---
# <a id='step3'></a>
#
# ## Step 3: Blur an Image and Perform Edge Detection

# %% [markdown]
# Now that we have developed a simple pipeline for detecting faces using OpenCV - let's start playing around with a few fun things we can do with all those detected faces!

# %% [markdown]
# ### Importance of Blur in Edge Detection
#
# Edge detection is a concept that pops up almost everywhere in computer vision applications, as edge-based features (as well as features built on top of edges) are often some of the best features for e.g., object detection and recognition problems.
#
# Edge detection is a dimension reduction technique - by keeping only the edges of an image we get to throw away a lot of non-discriminating information.  And typically the most useful kind of edge-detection is one that preserves only the important, global structures (ignoring local structures that aren't very discriminative).  So removing local structures / retaining global structures is a crucial pre-processing step to performing edge detection in an image, and blurring can do just that.
#
# Below is an animated gif showing the result of an edge-detected cat [taken from Wikipedia](https://en.wikipedia.org/wiki/Gaussian_blur#Common_uses), where the image is gradually blurred more and more prior to edge detection.  When the animation begins you can't quite make out what it's a picture of, but as the animation evolves and local structures are removed via blurring the cat becomes visible in the edge-detected image.
#
# <img src="images/Edge_Image.gif" width=400 height=300/>
#
# Edge detection is a **convolution** performed on the image itself, and you can read about Canny edge detection on [this OpenCV documentation page](http://docs.opencv.org/2.4/doc/tutorials/imgproc/imgtrans/canny_detector/canny_detector.html).

# %% [markdown]
# ### Canny edge detection
#
# In the cell below we load in a test image, then apply *Canny edge detection* on it.  The original image is shown on the left panel of the figure, while the edge-detected version of the image is shown on the right.  Notice how the result looks very busy - there are too many little details preserved in the image before it is sent to the edge detector.  When applied in computer vision applications, edge detection should preserve *global* structure; doing away with local structures that don't help describe what objects are in the image.

# %%
# Load in the image
image = cv2.imread('images/fawzia.jpg')

# Convert to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)  

# Perform Canny edge detection
edges = cv2.Canny(gray,100,200)

# Dilate the image to amplify edges
edges = cv2.dilate(edges, None)

# Plot the RGB and edge-detected image
fig = plt.figure(figsize = (15,15))
ax1 = fig.add_subplot(121)
ax1.set_xticks([])
ax1.set_yticks([])

ax1.set_title('Original Image')
ax1.imshow(image)

ax2 = fig.add_subplot(122)
ax2.set_xticks([])
ax2.set_yticks([])

ax2.set_title('Canny Edges')
ax2.imshow(edges, cmap='gray')

# %% [markdown]
# Without first blurring the image, and removing small, local structures, a lot of irrelevant edge content gets picked up and amplified by the detector (as shown in the right panel above).

# %% [markdown]
# ### (IMPLEMENTATION) Blur the image *then* perform edge detection
#
# In the next cell, you will repeat this experiment - blurring the image first to remove these local structures, so that only the important boudnary details remain in the edge-detected image.
#
# Blur the image by using OpenCV's ```filter2d``` functionality - which is discussed in [this documentation page](http://docs.opencv.org/3.1.0/d4/d13/tutorial_py_filtering.html) - and use an *averaging kernel* of width equal to 4.

# %%
### TODO: Blur the test imageusing OpenCV's filter2d functionality, 
# Use an averaging kernel, and a kernel width equal to 4

## TODO: Then perform Canny edge detection and display the output

# %% [markdown]
# ---
# <a id='step4'></a>
#
# ## Step 4: Automatically Hide the Identity of an Individual
#
# If you film something like a documentary or reality TV, you must get permission from every individual shown on film before you can show their face, otherwise you need to blur it out - by blurring the face a lot (so much so that even the global structures are obscured)!  This is also true for projects like [Google's StreetView maps](https://www.google.com/streetview/) - an enormous collection of mapping images taken from a fleet of Google vehicles.  Because it would be impossible for Google to get the permission of every single person accidentally captured in one of these images they blur out everyone's faces, the detected images must automatically blur the identity of detected people.  Here's a few examples of folks caught in the camera of a Google street view vehicle.
#
# <img src="images/streetview_example_1.jpg" width=400 height=300/>
# <img src="images/streetview_example_2.jpg" width=400 height=300/>

# %% [markdown]
# ### Read in an image to perform identity detection
#
# Let's try this out for ourselves.  Use the face detection pipeline built above and what you know about using the ```filter2D``` to blur and image, and use these in tandem to hide the identity of the person in the following image - loaded in and printed in the next cell.

# %%
# Load in the image
image = cv2.imread('images/gus.jpg')

# Convert the image to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
fig = plt.figure(figsize = (6,6))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title('Original Image')
ax1.imshow(image)

# %% [markdown]
# ### (IMPLEMENTATION) Use blurring to hide the identity of an individual in an image
#
# The idea here is to 1) automatically detect the face in this image, and then 2) blur it out!  Make sure to adjust the parameters of the *averaging* blur filter to completely obscure this person's identity.

# %%
## TODO: Implement face detection

## TODO: Blur the bounding box around each detected face using an averaging filter and display the result

# %% [markdown]
# ### (Optional) Build identity protection into your laptop camera
#
# In this optional task you can add identity protection to your laptop camera, using the previously completed code where you added face detection to your laptop camera - and the task above.  You should be able to get reasonable results with little parameter tuning - like the one shown in the gif below.
#
# <img src="images/laptop_blurer_example.gif" width=400 height=300/>
#
# As with the previous video task, to make this perfect would require significant effort - so don't strive for perfection here, strive for reasonable quality.
#
# The next cell contains code a wrapper function called ``laptop_camera_identity_hider`` that - when called  - will activate your laptop's camera.  You need to place the relevant face detection and blurring code developed above in this function in order to blur faces entering your laptop camera's field of view.
#
# Before adding anything to the function you can call it to get a hang of how it works - a small window will pop up showing you the live feed from your camera, you can press any key to close this window.
#
# **Note:** Mac users may find that activating this function kills the kernel of their notebook every once in a while.  If this happens to you, just restart your notebook's kernel, activate cell(s) containing any crucial import statements, and you'll be good to go!

# %%
### Insert face detection and blurring code into the wrapper below to create an identity protector on your laptop!
import cv2
import time 

def laptop_camera_go():
    # Create instance of video capturer
    cv2.namedWindow("face detection activated")
    vc = cv2.VideoCapture(0)

    # Try to get the first frame
    if vc.isOpened(): 
        rval, frame = vc.read()
    else:
        rval = False
    
    # Keep video stream open
    while rval:
        # Plot image from camera with detections marked
        cv2.imshow("face detection activated", frame)
        
        # Exit functionality - press any key to exit laptop video
        key = cv2.waitKey(20)
        if key > 0: # Exit by pressing any key
            # Destroy windows
            cv2.destroyAllWindows()
            
            for i in range (1,5):
                cv2.waitKey(1)
            return
        
        # Read next frame
        time.sleep(0.05)             # control framerate for computation - default 20 frames per sec
        rval, frame = vc.read()

# %%
# Run laptop identity hider
laptop_camera_go()

# %% [markdown]
# ---
# <a id='step5'></a>
#
# ## Step 5: Create a CNN to Recognize Facial Keypoints
#
# OpenCV is often used in practice with other machine learning and deep learning libraries to produce interesting results.  In this stage of the project you will create your own end-to-end pipeline - employing convolutional networks in keras along with OpenCV - to apply a "selfie" filter to streaming video and images.
#
# You will start by creating and then training a convolutional network that can detect facial keypoints in a small dataset of cropped images of human faces.  We then guide you towards OpenCV to expanding your detection algorithm to more general images.  What are facial keypoints?  Let's take a look at some examples.
#
# <img src="images/keypoints_test_results.png" width=400 height=300/>
#
# Facial keypoints (also called facial landmarks) are the small blue-green dots shown on each of the faces in the image above - there are 15 keypoints marked in each image.  They mark important areas of the face - the eyes, corners of the mouth, the nose, etc.  Facial keypoints can be used in a variety of machine learning applications from face and emotion recognition to commercial applications like the image filters popularized by Snapchat.
#
# Below we illustrate a filter that, using the results of this section, automatically places sunglasses on people in images (using the facial keypoints to place the glasses correctly on each face).  Here, the facial keypoints have been colored lime green for visualization purposes.
#
# <img src="images/obamas_with_shades.png" width=1000 height=1000/>

# %% [markdown]
# ### Make a facial keypoint detector
#
# But first things first: how can we make a facial keypoint detector?  Well, at a high level, notice that facial keypoint detection is a *regression problem*.  A single face corresponds to a set of 15 facial keypoints (a set of 15 corresponding $(x, y)$ coordinates, i.e., an output point).  Because our input data are images, we can employ a *convolutional neural network* to recognize patterns in our images and learn how to identify these keypoint given sets of labeled data.
#
# In order to train a regressor, we need a training set - a set of facial image / facial keypoint pairs to train on.  For this we will be using [this dataset from Kaggle](https://www.kaggle.com/c/facial-keypoints-detection/data). We've already downloaded this data and placed it in the `data` directory. Make sure that you have both the *training* and *test* data files.  The training dataset contains several thousand $96 \times 96$ grayscale images of cropped human faces, along with each face's 15 corresponding facial keypoints (also called landmarks) that have been placed by hand, and recorded in $(x, y)$ coordinates.  This wonderful resource also has a substantial testing set, which we will use in tinkering with our convolutional network.
#
# To load in this data, run the Python cell below - notice we will load in both the training and testing sets.
#
# The `load_data` function is in the included `utils.py` file.

# %%
from utils import *

# Load training set
X_train, y_train = load_data()
print("X_train.shape == {}".format(X_train.shape))
print("y_train.shape == {}; y_train.min == {:.3f}; y_train.max == {:.3f}".format(
    y_train.shape, y_train.min(), y_train.max()))

# Load testing set
X_test, _ = load_data(test=True)
print("X_test.shape == {}".format(X_test.shape))
# Out:
# Using TensorFlow backend.
# X_train.shape == (2140, 96, 96, 1)
# y_train.shape == (2140, 30); y_train.min == -0.920; y_train.max == 0.996
# X_test.shape == (1783, 96, 96, 1)

# %% [markdown]
# The `load_data` function in `utils.py` originates from this excellent [blog post](http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/), which you are *strongly* encouraged to read.  Please take the time now to review this function.  Note how the output values - that is, the coordinates of each set of facial landmarks - have been normalized to take on values in the range $[-1, 1]$, while the pixel values of each input point (a facial image) have been normalized to the range $[0,1]$.
#
# Note: the original Kaggle dataset contains some images with several missing keypoints.  For simplicity, the `load_data` function removes those images with missing labels from the dataset.  As an __*optional*__ extension, you are welcome to amend the `load_data` function to include the incomplete data points.

# %% [markdown]
# ### Visualize the Training Data
#
# Execute the code cell below to visualize a subset of the training data.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,20))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    plot_data(X_train[i], y_train[i], ax)

# %% [markdown]
# For each training image, there are two landmarks per eyebrow (**four** total), three per eye (**six** total), **four** for the mouth, and **one** for the tip of the nose.
#
# Review the `plot_data` function in `utils.py` to understand how the 30-dimensional training labels in `y_train` are mapped to facial locations, as this function will prove useful for your pipeline.

# %% [markdown]
# ### (IMPLEMENTATION) Specify the CNN Architecture
#
# In this section, you will specify a neural network for predicting the locations of facial keypoints.  Use the code cell below to specify the architecture of your neural network.  We have imported some layers that you may find useful for this task, but if you need to use more Keras layers, feel free to import them in the cell.
#
# Your network should accept a $96 \times 96$ grayscale image as input, and it should output a vector with 30 entries, corresponding to the predicted (horizontal and vertical) locations of 15 facial keypoints.  If you are not sure where to start, you can find some useful starting architectures in [this blog](http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/), but you are not permitted to copy any of the architectures that you find online.

# %%
# helpers for training CNNs
import keras
import timeit

# graph the history of model.fit
def show_history_graph(history, extra=''):
    # summarize history for accuracy
    print(history.history.keys())
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title(f'model accuracy {extra}')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()

    # summarize history for mean absolute error
    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title(f'model mean absolute error {extra}')
    plt.ylabel('error')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()
    
    # summarize history for mean absolute error
    plt.plot(history.history['mean_squared_error'])
    plt.plot(history.history['val_mean_squared_error'])
    plt.title(f'model mean squared error {extra}')
    plt.ylabel('error')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'model loss {extra}')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()

# %%
# Import deep learning resources from Keras
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, Dropout
from keras.layers import Flatten, Dense

# TODO: Specify a CNN architecture
# Your model should accept 96x96 pixel graysale images in
# It should have a fully-connected output layer with 30 values (2 for each facial keypoint)

# This is the lasagne network from:
# http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/
# pretty straight forwards Conv2D Max Pool type CNN network 

# layers=[
#     ('input', layers.InputLayer),
#     ('conv1', layers.Conv2DLayer),
#     ('pool1', layers.MaxPool2DLayer),
#     ('conv2', layers.Conv2DLayer),
#     ('pool2', layers.MaxPool2DLayer),
#     ('conv3', layers.Conv2DLayer),
#     ('pool3', layers.MaxPool2DLayer),
#     ('hidden4', layers.DenseLayer),
#     ('hidden5', layers.DenseLayer),
#     ('output', layers.DenseLayer),
#     ],
# input_shape=(None, 1, 96, 96),
# conv1_num_filters=32, conv1_filter_size=(3, 3), pool1_pool_size=(2, 2),
# conv2_num_filters=64, conv2_filter_size=(2, 2), pool2_pool_size=(2, 2),
# conv3_num_filters=128, conv3_filter_size=(2, 2), pool3_pool_size=(2, 2),
# hidden4_num_units=500, hidden5_num_units=500,
# output_num_units=30, output_nonlinearity=None,

model = Sequential()
model.add(Convolution2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(96, 96, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(filters=64, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(filters=128, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512)) # base 2 rather than 500 in lasagne network
model.add(Dense(512)) # base 2 rather than 500 in lasagne network
model.add(Dense(30))

# Summarize the model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 94, 94, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 46, 46, 64)        8256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 22, 22, 128)       32896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 15488)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               7744500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                15030
# =================================================================
# Total params: 8,051,502
# Trainable params: 8,051,502
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---
# <a id='step6'></a>
#
# ## Step 6: Compile and Train the Model
#
# After specifying your architecture, you'll need to compile and train the model to detect facial keypoints'

# %% [markdown]
# ### (IMPLEMENTATION) Compile and Train the Model
#
# Use the `compile` [method](https://keras.io/models/sequential/#sequential-model-methods) to configure the learning process.  Experiment with your choice of [optimizer](https://keras.io/optimizers/); you may have some ideas about which will work best (`SGD` vs. `RMSprop`, etc), but take the time to empirically verify your theories.
#
# Use the `fit` [method](https://keras.io/models/sequential/#sequential-model-methods) to train the model.  Break off a validation set by setting `validation_split=0.2`.  Save the returned `History` object in the `history` variable.
#
# Your model is required to attain a validation loss (measured as mean squared error) of at least **XYZ**.  When you have finished training, [save your model](https://keras.io/getting-started/faq/#how-can-i-save-a-keras-model) as an HDF5 file with file path `my_model.h5`.

# %%
from keras.optimizers import SGD, RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam

optimizers = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam', 'Nesterov']
mse_history = {}
epochs = 10
for optimizer in optimizers:
    # the lasagne network suggested using SGD Nesterov with lr 0.01 and momentum 0.9
    if optimizer == 'Nesterov':
        opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    else:
        opt = optimizer
    model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
    hist = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, verbose=0)
    mse_history[optimizer] = hist.history['mean_squared_error']

# %%
legend = []
plt.figure(figsize=(20, 10))
for key, opt in mse_history.items():
    plt.plot(opt)
    legend.append(key)

plt.title(f'optimizer mean squared error')
plt.ylabel('mean squared error')
plt.xlabel('epoch')
plt.legend(legend, loc='upper right')
plt.ylim(0, 0.01)
plt.show()

# %%
# Adam / Adamax seem to be doing the best here

# %%
opt = 'Adamax'
epochs = 10
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, shuffle=True)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/10
# 1712/1712 [==============================] - 2s - loss: 0.0101 - acc: 0.6425 - mean_absolute_error: 0.0720 - mean_squared_error: 0.0101 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0045
# Epoch 2/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0045
# Epoch 3/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0495 - val_mean_squared_error: 0.0046
# Epoch 4/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0044
# Epoch 5/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0044
# Epoch 6/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0046
# Epoch 7/10
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.7074 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_acc: 0.6963 - val_mean_absolute_error: 0.0504 - val_mean_squared_error: 0.0047
# Epoch 8/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0044
# Epoch 9/10
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.7074 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0497 - val_mean_squared_error: 0.0046
# Epoch 10/10
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.7074 - mean_absolute_error: 0.0493 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0500 - val_mean_squared_error: 0.0046
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# hrm... something looks broken, the accuracy is not moving, lets try adding some dropout

# %%
model2 = Sequential()
model2.add(Convolution2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(96, 96, 1)))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.5))

model2.add(Convolution2D(filters=64, kernel_size=(2, 2), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.5))

model2.add(Convolution2D(filters=128, kernel_size=(2, 2), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.5))

model2.add(Flatten())
model2.add(Dense(512)) # base 2 rather than 500 in lasagne network
model2.add(Dropout(0.5))
model2.add(Dense(512)) # base 2 rather than 500 in lasagne network
model2.add(Dropout(0.5))
model2.add(Dense(30))

# Summarize the model
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 94, 94, 32)        320
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 47, 47, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 46, 46, 64)        8256
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 22, 22, 128)       32896
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 11, 11, 128)       0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 15488)             0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               7930368
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 30)                15390
# =================================================================
# Total params: 8,249,886
# Trainable params: 8,249,886
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = 'Adamax'
epochs = 10
model2.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model2.fit(X_train, y_train, validation_split=0.2, epochs=epochs, shuffle=True)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/10
# 1712/1712 [==============================] - 2s - loss: 0.5740 - acc: 0.1752 - mean_absolute_error: 0.3963 - mean_squared_error: 0.5740 - val_loss: 0.1051 - val_acc: 0.6963 - val_mean_absolute_error: 0.2784 - val_mean_squared_error: 0.1051
# Epoch 2/10
# 1712/1712 [==============================] - 2s - loss: 0.0349 - acc: 0.2956 - mean_absolute_error: 0.1487 - mean_squared_error: 0.0349 - val_loss: 0.0522 - val_acc: 0.6963 - val_mean_absolute_error: 0.1945 - val_mean_squared_error: 0.0522
# Epoch 3/10
# 1712/1712 [==============================] - 2s - loss: 0.0277 - acc: 0.3102 - mean_absolute_error: 0.1319 - mean_squared_error: 0.0277 - val_loss: 0.0324 - val_acc: 0.6963 - val_mean_absolute_error: 0.1505 - val_mean_squared_error: 0.0324
# Epoch 4/10
# 1712/1712 [==============================] - 2s - loss: 0.0239 - acc: 0.3686 - mean_absolute_error: 0.1227 - mean_squared_error: 0.0239 - val_loss: 0.0252 - val_acc: 0.6963 - val_mean_absolute_error: 0.1319 - val_mean_squared_error: 0.0252
# Epoch 5/10
# 1712/1712 [==============================] - 2s - loss: 0.0218 - acc: 0.3633 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0218 - val_loss: 0.0193 - val_acc: 0.6963 - val_mean_absolute_error: 0.1125 - val_mean_squared_error: 0.0193
# Epoch 6/10
# 1712/1712 [==============================] - 2s - loss: 0.0199 - acc: 0.3861 - mean_absolute_error: 0.1119 - mean_squared_error: 0.0199 - val_loss: 0.0149 - val_acc: 0.6963 - val_mean_absolute_error: 0.0973 - val_mean_squared_error: 0.0149
# Epoch 7/10
# 1712/1712 [==============================] - 2s - loss: 0.0183 - acc: 0.4001 - mean_absolute_error: 0.1073 - mean_squared_error: 0.0183 - val_loss: 0.0113 - val_acc: 0.6963 - val_mean_absolute_error: 0.0835 - val_mean_squared_error: 0.0113
# Epoch 8/10
# 1712/1712 [==============================] - 2s - loss: 0.0174 - acc: 0.4001 - mean_absolute_error: 0.1043 - mean_squared_error: 0.0174 - val_loss: 0.0111 - val_acc: 0.6963 - val_mean_absolute_error: 0.0826 - val_mean_squared_error: 0.0111
# Epoch 9/10
# 1712/1712 [==============================] - 2s - loss: 0.0160 - acc: 0.4299 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0160 - val_loss: 0.0091 - val_acc: 0.6963 - val_mean_absolute_error: 0.0733 - val_mean_squared_error: 0.0091
# Epoch 10/10
# 1712/1712 [==============================] - 2s - loss: 0.0152 - acc: 0.4369 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0152 - val_loss: 0.0069 - val_acc: 0.6963 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0069
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# better but still something weird going on lets try more dimensionality reduction

# %%
model3 = Sequential()
model3.add(Convolution2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(96, 96, 1)))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.5))

model3.add(Convolution2D(filters=32, kernel_size=(2, 2), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.5))

model3.add(Convolution2D(filters=64, kernel_size=(2, 2), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.5))

model3.add(Flatten())
model3.add(Dense(512)) # base 2 rather than 500 in lasagne network
model3.add(Dropout(0.5))
model3.add(Dense(30))

# Summarize the model
model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 47, 47, 16)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 46, 46, 32)        2080
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 22, 22, 64)        8256
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 7744)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 512)               3965440
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 30)                15390
# =================================================================
# Total params: 3,991,326
# Trainable params: 3,991,326
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = 'Adamax'
epochs = 10
model3.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model3.fit(X_train, y_train, validation_split=0.2, epochs=epochs, shuffle=True)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/10
# 1712/1712 [==============================] - 2s - loss: 0.7258 - acc: 0.1893 - mean_absolute_error: 0.4767 - mean_squared_error: 0.7258 - val_loss: 0.1346 - val_acc: 0.4276 - val_mean_absolute_error: 0.3172 - val_mean_squared_error: 0.1346
# Epoch 2/10
# 1712/1712 [==============================] - 1s - loss: 0.0613 - acc: 0.2611 - mean_absolute_error: 0.1968 - mean_squared_error: 0.0613 - val_loss: 0.1345 - val_acc: 0.3692 - val_mean_absolute_error: 0.3167 - val_mean_squared_error: 0.1345
# Epoch 3/10
# 1712/1712 [==============================] - 1s - loss: 0.0529 - acc: 0.2745 - mean_absolute_error: 0.1832 - mean_squared_error: 0.0529 - val_loss: 0.1316 - val_acc: 0.3084 - val_mean_absolute_error: 0.3131 - val_mean_squared_error: 0.1316
# Epoch 4/10
# 1712/1712 [==============================] - 1s - loss: 0.0470 - acc: 0.2757 - mean_absolute_error: 0.1725 - mean_squared_error: 0.0470 - val_loss: 0.1273 - val_acc: 0.2477 - val_mean_absolute_error: 0.3077 - val_mean_squared_error: 0.1273
# Epoch 5/10
# 1712/1712 [==============================] - 1s - loss: 0.0421 - acc: 0.2804 - mean_absolute_error: 0.1631 - mean_squared_error: 0.0421 - val_loss: 0.1157 - val_acc: 0.2523 - val_mean_absolute_error: 0.2930 - val_mean_squared_error: 0.1157
# Epoch 6/10
# 1712/1712 [==============================] - 1s - loss: 0.0362 - acc: 0.3195 - mean_absolute_error: 0.1507 - mean_squared_error: 0.0362 - val_loss: 0.0803 - val_acc: 0.2523 - val_mean_absolute_error: 0.2436 - val_mean_squared_error: 0.0803
# Epoch 7/10
# 1712/1712 [==============================] - 1s - loss: 0.0293 - acc: 0.3487 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0293 - val_loss: 0.0417 - val_acc: 0.2523 - val_mean_absolute_error: 0.1717 - val_mean_squared_error: 0.0417
# Epoch 8/10
# 1712/1712 [==============================] - 1s - loss: 0.0251 - acc: 0.3464 - mean_absolute_error: 0.1251 - mean_squared_error: 0.0251 - val_loss: 0.0209 - val_acc: 0.3902 - val_mean_absolute_error: 0.1183 - val_mean_squared_error: 0.0209
# Epoch 9/10
# 1712/1712 [==============================] - 1s - loss: 0.0227 - acc: 0.3540 - mean_absolute_error: 0.1191 - mean_squared_error: 0.0227 - val_loss: 0.0129 - val_acc: 0.6963 - val_mean_absolute_error: 0.0897 - val_mean_squared_error: 0.0129
# Epoch 10/10
# 1712/1712 [==============================] - 1s - loss: 0.0210 - acc: 0.3785 - mean_absolute_error: 0.1146 - mean_squared_error: 0.0210 - val_loss: 0.0112 - val_acc: 0.6963 - val_mean_absolute_error: 0.0819 - val_mean_squared_error: 0.0112
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# lets reduce it more

# %%
model4 = Sequential()
model4.add(Convolution2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(96, 96, 1)))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.5))

model4.add(Convolution2D(filters=32, kernel_size=(2, 2), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.5))

model4.add(Convolution2D(filters=64, kernel_size=(2, 2), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.5))

model4.add(Flatten())
model4.add(Dense(256))
model4.add(Dropout(0.5))
model4.add(Dense(30))

# Summarize the model
model4.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_81 (Conv2D)           (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 47, 47, 16)        0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 46, 46, 32)        2080
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 22, 22, 64)        8256
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 7744)              0
# _________________________________________________________________
# dense_54 (Dense)             (None, 256)               1982720
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 30)                7710
# =================================================================
# Total params: 2,000,926
# Trainable params: 2,000,926
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = 'Adamax'
epochs = 30
model4.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model4.fit(X_train, y_train, validation_split=0.2, epochs=epochs, shuffle=True)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/30
# 1712/1712 [==============================] - 2s - loss: 0.0148 - acc: 0.4544 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0148 - val_loss: 0.0048 - val_acc: 0.6963 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0048
# Epoch 2/30
# 1712/1712 [==============================] - 1s - loss: 0.0091 - acc: 0.5824 - mean_absolute_error: 0.0737 - mean_squared_error: 0.0091 - val_loss: 0.0047 - val_acc: 0.6963 - val_mean_absolute_error: 0.0507 - val_mean_squared_error: 0.0047
# Epoch 3/30
# 1712/1712 [==============================] - 1s - loss: 0.0077 - acc: 0.5929 - mean_absolute_error: 0.0671 - mean_squared_error: 0.0077 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0500 - val_mean_squared_error: 0.0046
# Epoch 4/30
# 1712/1712 [==============================] - 1s - loss: 0.0071 - acc: 0.6157 - mean_absolute_error: 0.0641 - mean_squared_error: 0.0071 - val_loss: 0.0050 - val_acc: 0.6963 - val_mean_absolute_error: 0.0526 - val_mean_squared_error: 0.0050
# Epoch 5/30
# 1712/1712 [==============================] - 1s - loss: 0.0064 - acc: 0.6449 - mean_absolute_error: 0.0606 - mean_squared_error: 0.0064 - val_loss: 0.0051 - val_acc: 0.6963 - val_mean_absolute_error: 0.0533 - val_mean_squared_error: 0.0051
# Epoch 6/30
# 1712/1712 [==============================] - 1s - loss: 0.0060 - acc: 0.6589 - mean_absolute_error: 0.0583 - mean_squared_error: 0.0060 - val_loss: 0.0051 - val_acc: 0.6963 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0051
# Epoch 7/30
# 1712/1712 [==============================] - 1s - loss: 0.0058 - acc: 0.6577 - mean_absolute_error: 0.0572 - mean_squared_error: 0.0058 - val_loss: 0.0052 - val_acc: 0.6963 - val_mean_absolute_error: 0.0533 - val_mean_squared_error: 0.0052
# Epoch 8/30
# 1712/1712 [==============================] - 1s - loss: 0.0056 - acc: 0.6711 - mean_absolute_error: 0.0558 - mean_squared_error: 0.0056 - val_loss: 0.0047 - val_acc: 0.6963 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0047
# Epoch 9/30
# 1712/1712 [==============================] - 1s - loss: 0.0054 - acc: 0.6787 - mean_absolute_error: 0.0553 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_acc: 0.6963 - val_mean_absolute_error: 0.0517 - val_mean_squared_error: 0.0048
# Epoch 10/30
# 1712/1712 [==============================] - 1s - loss: 0.0053 - acc: 0.6776 - mean_absolute_error: 0.0541 - mean_squared_error: 0.0053 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0499 - val_mean_squared_error: 0.0046
# Epoch 11/30
# 1712/1712 [==============================] - 1s - loss: 0.0053 - acc: 0.6822 - mean_absolute_error: 0.0542 - mean_squared_error: 0.0053 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0044
# Epoch 12/30
# 1712/1712 [==============================] - 1s - loss: 0.0052 - acc: 0.6933 - mean_absolute_error: 0.0536 - mean_squared_error: 0.0052 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0496 - val_mean_squared_error: 0.0046
# Epoch 13/30
# 1712/1712 [==============================] - 1s - loss: 0.0051 - acc: 0.6822 - mean_absolute_error: 0.0527 - mean_squared_error: 0.0051 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0044
# Epoch 14/30
# 1712/1712 [==============================] - 1s - loss: 0.0050 - acc: 0.6834 - mean_absolute_error: 0.0527 - mean_squared_error: 0.0050 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0501 - val_mean_squared_error: 0.0046
# Epoch 15/30
# 1712/1712 [==============================] - 1s - loss: 0.0050 - acc: 0.6945 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0050 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0494 - val_mean_squared_error: 0.0045
# Epoch 16/30
# 1712/1712 [==============================] - 1s - loss: 0.0049 - acc: 0.7004 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0049 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0044
# Epoch 17/30
# 1712/1712 [==============================] - 1s - loss: 0.0048 - acc: 0.6992 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0048 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0045
# Epoch 18/30
# 1712/1712 [==============================] - 1s - loss: 0.0048 - acc: 0.6974 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0048 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0044
# Epoch 19/30
# 1712/1712 [==============================] - 1s - loss: 0.0047 - acc: 0.7015 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0047 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0045
# Epoch 20/30
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.6992 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0497 - val_mean_squared_error: 0.0046
# Epoch 21/30
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.6910 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0046 - val_loss: 0.0043 - val_acc: 0.6963 - val_mean_absolute_error: 0.0485 - val_mean_squared_error: 0.0043
# Epoch 22/30
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.6992 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0046 - val_loss: 0.0043 - val_acc: 0.6963 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0043
# Epoch 23/30
# 1712/1712 [==============================] - 1s - loss: 0.0044 - acc: 0.6945 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0045
# Epoch 24/30
# 1712/1712 [==============================] - 1s - loss: 0.0044 - acc: 0.6968 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0044 - val_loss: 0.0040 - val_acc: 0.6963 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0040
# Epoch 25/30
# 1712/1712 [==============================] - 1s - loss: 0.0043 - acc: 0.6974 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0043 - val_loss: 0.0040 - val_acc: 0.6963 - val_mean_absolute_error: 0.0462 - val_mean_squared_error: 0.0040
# Epoch 26/30
# 1712/1712 [==============================] - 1s - loss: 0.0042 - acc: 0.7033 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0042 - val_loss: 0.0038 - val_acc: 0.6963 - val_mean_absolute_error: 0.0448 - val_mean_squared_error: 0.0038
# Epoch 27/30
# 1712/1712 [==============================] - 1s - loss: 0.0041 - acc: 0.7033 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0041 - val_loss: 0.0036 - val_acc: 0.6963 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0036
# Epoch 28/30
# 1712/1712 [==============================] - 1s - loss: 0.0039 - acc: 0.6986 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0039 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0431 - val_mean_squared_error: 0.0035
# Epoch 29/30
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.6968 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0422 - val_mean_squared_error: 0.0034
# Epoch 30/30
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.6992 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0037 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0033
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# lets see nesterov momentum for comparison

# %%
opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
epochs = 30
model4.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model4.fit(X_train, y_train, validation_split=0.2, epochs=epochs, shuffle=True)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/30
# 1712/1712 [==============================] - 2s - loss: 0.0037 - acc: 0.7021 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0037 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0410 - val_mean_squared_error: 0.0032
# Epoch 2/30
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7033 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0412 - val_mean_squared_error: 0.0032
# Epoch 3/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7027 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0035 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0032
# Epoch 4/30
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7027 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0032
# Epoch 5/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7033 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0407 - val_mean_squared_error: 0.0031
# Epoch 6/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7091 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0031
# Epoch 7/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.6945 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 8/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.6933 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 9/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.6968 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0031
# Epoch 10/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.6939 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 11/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7056 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 12/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7056 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 13/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7033 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 14/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7126 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0030
# Epoch 15/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.6992 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0030
# Epoch 16/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7009 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 17/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7085 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0030
# Epoch 18/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7068 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0030
# Epoch 19/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7050 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0030
# Epoch 20/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7015 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 21/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7015 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0030
# Epoch 22/30
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7062 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 23/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.6974 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0389 - val_mean_squared_error: 0.0029
# Epoch 24/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7068 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 25/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7074 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 26/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7039 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 27/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.6986 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 28/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7079 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6986 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0029
# Epoch 29/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7068 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 30/30
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7091 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# wow quite jumpy but it gets there as well maybe we can smooth it out by making the drop out more progressive
# also looks like we could try relu activation on the dense layer

# %%
model5 = Sequential()
model5.add(Convolution2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(96, 96, 1)))
model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(0.1))

model5.add(Convolution2D(filters=32, kernel_size=(2, 2), activation='relu'))
model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(0.2))

model5.add(Convolution2D(filters=64, kernel_size=(2, 2), activation='relu'))
model5.add(MaxPooling2D(pool_size=(2, 2)))
model5.add(Dropout(0.3))

model5.add(Flatten())
model5.add(Dense(256, activation='relu'))
model5.add(Dropout(0.5))
model5.add(Dense(30))

# Summarize the model
model5.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_90 (Conv2D)           (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_85 (MaxPooling (None, 47, 47, 16)        0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_91 (Conv2D)           (None, 46, 46, 32)        2080
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 22, 22, 64)        8256
# _________________________________________________________________
# max_pooling2d_87 (MaxPooling (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 7744)              0
# _________________________________________________________________
# dense_60 (Dense)             (None, 256)               1982720
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 30)                7710
# =================================================================
# Total params: 2,000,926
# Trainable params: 2,000,926
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = 'Adamax'
epochs = 30
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train, y_train, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/30
# 1712/1712 [==============================] - 2s - loss: 0.0682 - acc: 0.2921 - mean_absolute_error: 0.1996 - mean_squared_error: 0.0682 - val_loss: 0.0761 - val_acc: 0.6963 - val_mean_absolute_error: 0.2349 - val_mean_squared_error: 0.0761
# Epoch 2/30
# 1712/1712 [==============================] - 1s - loss: 0.0249 - acc: 0.3627 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0249 - val_loss: 0.0567 - val_acc: 0.6729 - val_mean_absolute_error: 0.1985 - val_mean_squared_error: 0.0567
# Epoch 3/30
# 1712/1712 [==============================] - 1s - loss: 0.0187 - acc: 0.4188 - mean_absolute_error: 0.1071 - mean_squared_error: 0.0187 - val_loss: 0.0479 - val_acc: 0.6893 - val_mean_absolute_error: 0.1816 - val_mean_squared_error: 0.0479
# Epoch 4/30
# 1712/1712 [==============================] - 1s - loss: 0.0154 - acc: 0.4556 - mean_absolute_error: 0.0966 - mean_squared_error: 0.0154 - val_loss: 0.0461 - val_acc: 0.6893 - val_mean_absolute_error: 0.1788 - val_mean_squared_error: 0.0461
# Epoch 5/30
# 1712/1712 [==============================] - 1s - loss: 0.0141 - acc: 0.5041 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0141 - val_loss: 0.0407 - val_acc: 0.6963 - val_mean_absolute_error: 0.1677 - val_mean_squared_error: 0.0407
# Epoch 6/30
# 1712/1712 [==============================] - 1s - loss: 0.0130 - acc: 0.5199 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0130 - val_loss: 0.0377 - val_acc: 0.6963 - val_mean_absolute_error: 0.1613 - val_mean_squared_error: 0.0377
# Epoch 7/30
# 1712/1712 [==============================] - 1s - loss: 0.0119 - acc: 0.5310 - mean_absolute_error: 0.0837 - mean_squared_error: 0.0119 - val_loss: 0.0318 - val_acc: 0.6963 - val_mean_absolute_error: 0.1464 - val_mean_squared_error: 0.0318
# Epoch 8/30
# 1712/1712 [==============================] - 1s - loss: 0.0112 - acc: 0.5473 - mean_absolute_error: 0.0812 - mean_squared_error: 0.0112 - val_loss: 0.0319 - val_acc: 0.6963 - val_mean_absolute_error: 0.1462 - val_mean_squared_error: 0.0319
# Epoch 9/30
# 1712/1712 [==============================] - 1s - loss: 0.0107 - acc: 0.5403 - mean_absolute_error: 0.0791 - mean_squared_error: 0.0107 - val_loss: 0.0325 - val_acc: 0.6963 - val_mean_absolute_error: 0.1487 - val_mean_squared_error: 0.0325
# Epoch 10/30
# 1712/1712 [==============================] - 1s - loss: 0.0103 - acc: 0.5631 - mean_absolute_error: 0.0775 - mean_squared_error: 0.0103 - val_loss: 0.0219 - val_acc: 0.6963 - val_mean_absolute_error: 0.1186 - val_mean_squared_error: 0.0219
# Epoch 11/30
# 1712/1712 [==============================] - 1s - loss: 0.0098 - acc: 0.5794 - mean_absolute_error: 0.0755 - mean_squared_error: 0.0098 - val_loss: 0.0233 - val_acc: 0.6963 - val_mean_absolute_error: 0.1231 - val_mean_squared_error: 0.0233
# Epoch 12/30
# 1712/1712 [==============================] - 1s - loss: 0.0093 - acc: 0.5929 - mean_absolute_error: 0.0736 - mean_squared_error: 0.0093 - val_loss: 0.0217 - val_acc: 0.6963 - val_mean_absolute_error: 0.1182 - val_mean_squared_error: 0.0217
# Epoch 13/30
# 1712/1712 [==============================] - 1s - loss: 0.0090 - acc: 0.5999 - mean_absolute_error: 0.0722 - mean_squared_error: 0.0090 - val_loss: 0.0217 - val_acc: 0.6963 - val_mean_absolute_error: 0.1191 - val_mean_squared_error: 0.0217
# Epoch 14/30
# 1712/1712 [==============================] - 1s - loss: 0.0088 - acc: 0.5993 - mean_absolute_error: 0.0713 - mean_squared_error: 0.0088 - val_loss: 0.0183 - val_acc: 0.6963 - val_mean_absolute_error: 0.1076 - val_mean_squared_error: 0.0183
# Epoch 15/30
# 1712/1712 [==============================] - 1s - loss: 0.0085 - acc: 0.5970 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0085 - val_loss: 0.0143 - val_acc: 0.6963 - val_mean_absolute_error: 0.0941 - val_mean_squared_error: 0.0143
# Epoch 16/30
# 1712/1712 [==============================] - 1s - loss: 0.0080 - acc: 0.6273 - mean_absolute_error: 0.0677 - mean_squared_error: 0.0080 - val_loss: 0.0117 - val_acc: 0.6963 - val_mean_absolute_error: 0.0839 - val_mean_squared_error: 0.0117
# Epoch 17/30
# 1712/1712 [==============================] - 1s - loss: 0.0079 - acc: 0.6303 - mean_absolute_error: 0.0670 - mean_squared_error: 0.0079 - val_loss: 0.0114 - val_acc: 0.6963 - val_mean_absolute_error: 0.0826 - val_mean_squared_error: 0.0114
# Epoch 18/30
# 1712/1712 [==============================] - 1s - loss: 0.0077 - acc: 0.6291 - mean_absolute_error: 0.0662 - mean_squared_error: 0.0077 - val_loss: 0.0117 - val_acc: 0.6963 - val_mean_absolute_error: 0.0839 - val_mean_squared_error: 0.0117
# Epoch 19/30
# 1712/1712 [==============================] - 1s - loss: 0.0071 - acc: 0.6396 - mean_absolute_error: 0.0634 - mean_squared_error: 0.0071 - val_loss: 0.0100 - val_acc: 0.6963 - val_mean_absolute_error: 0.0767 - val_mean_squared_error: 0.0100
# Epoch 20/30
# 1712/1712 [==============================] - 1s - loss: 0.0071 - acc: 0.6449 - mean_absolute_error: 0.0635 - mean_squared_error: 0.0071 - val_loss: 0.0104 - val_acc: 0.6963 - val_mean_absolute_error: 0.0786 - val_mean_squared_error: 0.0104
# Epoch 21/30
# 1712/1712 [==============================] - 1s - loss: 0.0068 - acc: 0.6367 - mean_absolute_error: 0.0618 - mean_squared_error: 0.0068 - val_loss: 0.0089 - val_acc: 0.6963 - val_mean_absolute_error: 0.0721 - val_mean_squared_error: 0.0089
# Epoch 22/30
# 1712/1712 [==============================] - 1s - loss: 0.0066 - acc: 0.6554 - mean_absolute_error: 0.0609 - mean_squared_error: 0.0066 - val_loss: 0.0079 - val_acc: 0.6963 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0079
# Epoch 23/30
# 1712/1712 [==============================] - 1s - loss: 0.0064 - acc: 0.6694 - mean_absolute_error: 0.0598 - mean_squared_error: 0.0064 - val_loss: 0.0100 - val_acc: 0.6963 - val_mean_absolute_error: 0.0771 - val_mean_squared_error: 0.0100
# Epoch 24/30
# 1712/1712 [==============================] - 1s - loss: 0.0061 - acc: 0.6671 - mean_absolute_error: 0.0587 - mean_squared_error: 0.0061 - val_loss: 0.0069 - val_acc: 0.6963 - val_mean_absolute_error: 0.0626 - val_mean_squared_error: 0.0069
# Epoch 25/30
# 1712/1712 [==============================] - 1s - loss: 0.0060 - acc: 0.6595 - mean_absolute_error: 0.0580 - mean_squared_error: 0.0060 - val_loss: 0.0064 - val_acc: 0.6963 - val_mean_absolute_error: 0.0599 - val_mean_squared_error: 0.0064
# Epoch 26/30
# 1712/1712 [==============================] - 1s - loss: 0.0057 - acc: 0.6700 - mean_absolute_error: 0.0568 - mean_squared_error: 0.0057 - val_loss: 0.0061 - val_acc: 0.6963 - val_mean_absolute_error: 0.0585 - val_mean_squared_error: 0.0061
# Epoch 27/30
# 1712/1712 [==============================] - 1s - loss: 0.0056 - acc: 0.6764 - mean_absolute_error: 0.0561 - mean_squared_error: 0.0056 - val_loss: 0.0053 - val_acc: 0.6963 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0053
# Epoch 28/30
# 1712/1712 [==============================] - 1s - loss: 0.0053 - acc: 0.6980 - mean_absolute_error: 0.0544 - mean_squared_error: 0.0053 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0498 - val_mean_squared_error: 0.0046
# Epoch 29/30
# 1712/1712 [==============================] - 1s - loss: 0.0051 - acc: 0.6828 - mean_absolute_error: 0.0533 - mean_squared_error: 0.0051 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0495 - val_mean_squared_error: 0.0045
# Epoch 30/30
# 1712/1712 [==============================] - 1s - loss: 0.0049 - acc: 0.6863 - mean_absolute_error: 0.0521 - mean_squared_error: 0.0049 - val_loss: 0.0046 - val_acc: 0.6963 - val_mean_absolute_error: 0.0505 - val_mean_squared_error: 0.0046
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
epochs = 30
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train, y_train, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/30
# 1712/1712 [==============================] - 2s - loss: 0.0048 - acc: 0.6764 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0048 - val_loss: 0.0044 - val_acc: 0.6963 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0044
# Epoch 2/30
# 1712/1712 [==============================] - 1s - loss: 0.0048 - acc: 0.6916 - mean_absolute_error: 0.0513 - mean_squared_error: 0.0048 - val_loss: 0.0042 - val_acc: 0.6963 - val_mean_absolute_error: 0.0475 - val_mean_squared_error: 0.0042
# Epoch 3/30
# 1712/1712 [==============================] - 1s - loss: 0.0047 - acc: 0.6928 - mean_absolute_error: 0.0509 - mean_squared_error: 0.0047 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0490 - val_mean_squared_error: 0.0045
# Epoch 4/30
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.6945 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0046 - val_loss: 0.0042 - val_acc: 0.6963 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0042
# Epoch 5/30
# 1712/1712 [==============================] - 1s - loss: 0.0046 - acc: 0.6922 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_acc: 0.6963 - val_mean_absolute_error: 0.0493 - val_mean_squared_error: 0.0045
# Epoch 6/30
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.6898 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0045 - val_loss: 0.0039 - val_acc: 0.6963 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0039
# Epoch 7/30
# 1712/1712 [==============================] - 1s - loss: 0.0045 - acc: 0.6939 - mean_absolute_error: 0.0499 - mean_squared_error: 0.0045 - val_loss: 0.0040 - val_acc: 0.6963 - val_mean_absolute_error: 0.0463 - val_mean_squared_error: 0.0040
# Epoch 8/30
# 1712/1712 [==============================] - 1s - loss: 0.0044 - acc: 0.6863 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0044 - val_loss: 0.0038 - val_acc: 0.6963 - val_mean_absolute_error: 0.0448 - val_mean_squared_error: 0.0038
# Epoch 9/30
# 1712/1712 [==============================] - 1s - loss: 0.0044 - acc: 0.7039 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0044 - val_loss: 0.0040 - val_acc: 0.6963 - val_mean_absolute_error: 0.0462 - val_mean_squared_error: 0.0040
# Epoch 10/30
# 1712/1712 [==============================] - 1s - loss: 0.0044 - acc: 0.6945 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0044 - val_loss: 0.0037 - val_acc: 0.6963 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0037
# Epoch 11/30
# 1712/1712 [==============================] - 1s - loss: 0.0043 - acc: 0.6998 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0043 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0035
# Epoch 12/30
# 1712/1712 [==============================] - 1s - loss: 0.0043 - acc: 0.6898 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0043 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0034
# Epoch 13/30
# 1712/1712 [==============================] - 1s - loss: 0.0043 - acc: 0.7050 - mean_absolute_error: 0.0485 - mean_squared_error: 0.0043 - val_loss: 0.0036 - val_acc: 0.6963 - val_mean_absolute_error: 0.0434 - val_mean_squared_error: 0.0036
# Epoch 14/30
# 1712/1712 [==============================] - 1s - loss: 0.0043 - acc: 0.7039 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0043 - val_loss: 0.0036 - val_acc: 0.6963 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0036
# Epoch 15/30
# 1712/1712 [==============================] - 1s - loss: 0.0043 - acc: 0.6986 - mean_absolute_error: 0.0485 - mean_squared_error: 0.0043 - val_loss: 0.0040 - val_acc: 0.6963 - val_mean_absolute_error: 0.0465 - val_mean_squared_error: 0.0040
# Epoch 16/30
# 1712/1712 [==============================] - 1s - loss: 0.0042 - acc: 0.7044 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0042 - val_loss: 0.0036 - val_acc: 0.6963 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0036
# Epoch 17/30
# 1712/1712 [==============================] - 1s - loss: 0.0041 - acc: 0.7015 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0041 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0428 - val_mean_squared_error: 0.0035
# Epoch 18/30
# 1712/1712 [==============================] - 1s - loss: 0.0041 - acc: 0.7068 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0041 - val_loss: 0.0037 - val_acc: 0.6963 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0037
# Epoch 19/30
# 1712/1712 [==============================] - 1s - loss: 0.0041 - acc: 0.7074 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0041 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0035
# Epoch 20/30
# 1712/1712 [==============================] - 1s - loss: 0.0040 - acc: 0.7015 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0035
# Epoch 21/30
# 1712/1712 [==============================] - 1s - loss: 0.0041 - acc: 0.7044 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0041 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0034
# Epoch 22/30
# 1712/1712 [==============================] - 1s - loss: 0.0040 - acc: 0.7021 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0035
# Epoch 23/30
# 1712/1712 [==============================] - 1s - loss: 0.0040 - acc: 0.7039 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0432 - val_mean_squared_error: 0.0035
# Epoch 24/30
# 1712/1712 [==============================] - 1s - loss: 0.0041 - acc: 0.7062 - mean_absolute_error: 0.0471 - mean_squared_error: 0.0041 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0426 - val_mean_squared_error: 0.0034
# Epoch 25/30
# 1712/1712 [==============================] - 1s - loss: 0.0040 - acc: 0.7015 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0040 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0034
# Epoch 26/30
# 1712/1712 [==============================] - 1s - loss: 0.0040 - acc: 0.6968 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0040 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0417 - val_mean_squared_error: 0.0033
# Epoch 27/30
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7021 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0038 - val_loss: 0.0035 - val_acc: 0.6963 - val_mean_absolute_error: 0.0432 - val_mean_squared_error: 0.0035
# Epoch 28/30
# 1712/1712 [==============================] - 1s - loss: 0.0039 - acc: 0.7085 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0039 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0034
# Epoch 29/30
# 1712/1712 [==============================] - 1s - loss: 0.0039 - acc: 0.7056 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0039 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0034
# Epoch 30/30
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7068 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0034
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# lets add more data with data augmentation by horizontally flipping all the images and labels

# %%
X_train.shape
# Out:
# (2140, 96, 96, 1)

# %%
X_train_flipped = np.flip(np.copy(X_train), axis=2)

# %%
fig = plt.figure(figsize=(20,20))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    plot_data(X_train_flipped[i], y_train[i], ax)

# %%
y_train.shape
# Out:
# (2140, 30)

# %%
# now we need to flip the x values which are even indexes
flipped_indices = [
    (0, 2), (1, 3),
    (4, 8), (5, 9), (6, 10), (7, 11),
    (12, 16), (13, 17), (14, 18), (15, 19),
    (22, 24), (23, 25)
]

y_train_flipped = np.copy(y_train)

points = y_train_flipped.shape[1]
for i in range(len(y_train_flipped)):
    for x in range(0, points, 2):
        y_train_flipped[i][x] *= -1
        
    for (a, b) in flipped_indices:
        y_train_flipped[i][a], y_train_flipped[i][b] = y_train_flipped[i][b], y_train_flipped[i][a]

# %%
fig = plt.figure(figsize=(20,20))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    plot_data(X_train_flipped[i], y_train_flipped[i], ax)

# %%
#combine data sets

# %%
X_train_all = np.concatenate((X_train, X_train_flipped), axis=0)
y_train_all = np.concatenate((y_train, y_train_flipped), axis=0)
# from sklearn.utils import shuffle
# X_train_all, y_train_all = shuffle(X_train_all, y_train_all, random_state=42)

# %%
# make sure we didn't stuff anything up
fig = plt.figure(figsize=(20,20))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    plot_data(X_train_all[i], y_train_all[i], ax)

# %%
X_train_all.shape
# Out:
# (4280, 96, 96, 1)

# %%
opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
epochs = 100
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train, y_train, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/100
# 1712/1712 [==============================] - 2s - loss: 0.0039 - acc: 0.7033 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0039 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0420 - val_mean_squared_error: 0.0034
# Epoch 2/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7062 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0038 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0033
# Epoch 3/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7062 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0034
# Epoch 4/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7033 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0422 - val_mean_squared_error: 0.0034
# Epoch 5/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7138 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0038 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0419 - val_mean_squared_error: 0.0033
# Epoch 6/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7109 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0038 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0033
# Epoch 7/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7039 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_acc: 0.6963 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0034
# Epoch 8/100
# 1712/1712 [==============================] - 1s - loss: 0.0038 - acc: 0.7138 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0038 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0412 - val_mean_squared_error: 0.0032
# Epoch 9/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7039 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0037 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0032
# Epoch 10/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7109 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0037 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0033
# Epoch 11/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7056 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0037 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0032
# Epoch 12/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7085 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0037 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0032
# Epoch 13/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7079 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0037 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0415 - val_mean_squared_error: 0.0033
# Epoch 14/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7085 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0032
# Epoch 15/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7120 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0037 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 16/100
# 1712/1712 [==============================] - 1s - loss: 0.0037 - acc: 0.7103 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0037 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0032
# Epoch 17/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7044 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0032
# Epoch 18/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7068 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0032
# Epoch 19/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7120 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0032
# Epoch 20/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7079 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0036 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 21/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7039 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0032
# Epoch 22/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7085 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0032
# Epoch 23/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7027 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0036 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 24/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7039 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0036 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 25/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7062 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 26/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7074 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 27/100
# 1712/1712 [==============================] - 1s - loss: 0.0036 - acc: 0.7056 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0032
# Epoch 28/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7044 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 29/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7097 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 30/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7097 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 31/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7109 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0035 - val_loss: 0.0033 - val_acc: 0.6963 - val_mean_absolute_error: 0.0420 - val_mean_squared_error: 0.0033
# Epoch 32/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7109 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 33/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7074 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 34/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7062 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0031
# Epoch 35/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7079 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 36/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7085 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 37/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7050 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 38/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7091 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 39/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7085 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0031
# Epoch 40/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7062 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0032 - val_acc: 0.6963 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0032
# Epoch 41/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7074 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0031
# Epoch 42/100
# 1712/1712 [==============================] - 1s - loss: 0.0035 - acc: 0.7091 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0031
# Epoch 43/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7091 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 44/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7062 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 45/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7103 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 46/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7062 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0031
# Epoch 47/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7079 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 48/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7085 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 49/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7050 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 50/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7074 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 51/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7068 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 52/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7091 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 53/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7114 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 54/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7109 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 55/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7091 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0031
# Epoch 56/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7068 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 57/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7103 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 58/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7085 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 59/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 60/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7074 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 61/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 62/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7074 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 63/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7132 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0029
# Epoch 64/100
# 1712/1712 [==============================] - 1s - loss: 0.0034 - acc: 0.7103 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 65/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7074 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 66/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7044 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 67/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7062 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 68/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7044 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 69/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0030
# Epoch 70/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 71/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7079 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0031
# Epoch 72/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7068 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 73/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7050 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0029
# Epoch 74/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6963 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0031
# Epoch 75/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7074 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0030
# Epoch 76/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7068 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 77/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 78/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7079 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 79/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7062 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0030
# Epoch 80/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7097 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0029
# Epoch 81/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 82/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7068 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 83/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7085 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 84/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7062 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 85/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 86/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7097 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 87/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7079 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 88/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7091 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 89/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7079 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 90/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7074 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 91/100
# 1712/1712 [==============================] - 1s - loss: 0.0033 - acc: 0.7033 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0030
# Epoch 92/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7074 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 93/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7085 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 94/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7044 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0030
# Epoch 95/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7062 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 96/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7079 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 97/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7091 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 98/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7097 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6963 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 99/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7085 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 100/100
# 1712/1712 [==============================] - 1s - loss: 0.0032 - acc: 0.7044 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6963 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0030
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
epochs = 100
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train_all, y_train_all, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/100
# 3424/3424 [==============================] - 3s - loss: 0.0034 - acc: 0.6901 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0034 - val_loss: 0.0032 - val_acc: 0.6600 - val_mean_absolute_error: 0.0413 - val_mean_squared_error: 0.0032
# Epoch 2/100
# 3424/3424 [==============================] - 2s - loss: 0.0034 - acc: 0.6898 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0034 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0031
# Epoch 3/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6898 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0407 - val_mean_squared_error: 0.0031
# Epoch 4/100
# 3424/3424 [==============================] - 2s - loss: 0.0034 - acc: 0.6919 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0034 - val_loss: 0.0032 - val_acc: 0.6600 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0032
# Epoch 5/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6913 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 6/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6907 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0031
# Epoch 7/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6933 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 8/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6887 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 9/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6928 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 10/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6922 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 11/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6916 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 12/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6922 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0407 - val_mean_squared_error: 0.0031
# Epoch 13/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6930 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0407 - val_mean_squared_error: 0.0031
# Epoch 14/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6939 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 15/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6919 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 16/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6933 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 17/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6907 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0030
# Epoch 18/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6910 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 19/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6936 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0031
# Epoch 20/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6904 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 21/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6925 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 22/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6890 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0032 - val_acc: 0.6600 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0032
# Epoch 23/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6890 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 24/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6919 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0031
# Epoch 25/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6907 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0030
# Epoch 26/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6963 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0031
# Epoch 27/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6925 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 28/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6933 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0401 - val_mean_squared_error: 0.0030
# Epoch 29/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6887 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 30/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6910 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 31/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6898 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0030
# Epoch 32/100
# 3424/3424 [==============================] - 2s - loss: 0.0033 - acc: 0.6960 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0033 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 33/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6916 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 34/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6907 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 35/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6928 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 36/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6913 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 37/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6901 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0030
# Epoch 38/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6895 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 39/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6936 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_acc: 0.6600 - val_mean_absolute_error: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 40/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6910 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 41/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6939 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 42/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6942 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 43/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6928 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 44/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6925 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 45/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6922 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 46/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6960 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 47/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6910 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0030
# Epoch 48/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6933 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0030
# Epoch 49/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6928 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 50/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6930 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 51/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6939 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 52/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6930 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0397 - val_mean_squared_error: 0.0030
# Epoch 53/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6939 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 54/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6910 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 55/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6933 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0031 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0030
# Epoch 56/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6922 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0029
# Epoch 57/100
# 3424/3424 [==============================] - 2s - loss: 0.0032 - acc: 0.6893 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 58/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6930 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 59/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6945 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 60/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6966 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 61/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6928 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0031 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 62/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6922 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 63/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6951 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0029
# Epoch 64/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6971 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 65/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6945 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 66/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6951 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 67/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6960 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0029
# Epoch 68/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6939 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 69/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6966 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 70/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6942 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0029
# Epoch 71/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6898 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 72/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6942 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 73/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6913 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 74/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6960 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0028
# Epoch 75/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6957 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0029
# Epoch 76/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6922 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 77/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6936 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0029
# Epoch 78/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6951 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0028
# Epoch 79/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6954 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0031 - val_loss: 0.0030 - val_acc: 0.6600 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0030
# Epoch 80/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6928 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0028
# Epoch 81/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6925 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 82/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6971 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0389 - val_mean_squared_error: 0.0029
# Epoch 83/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6930 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0028
# Epoch 84/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6916 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0028
# Epoch 85/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6933 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0389 - val_mean_squared_error: 0.0029
# Epoch 86/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6948 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0029
# Epoch 87/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6930 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0385 - val_mean_squared_error: 0.0028
# Epoch 88/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6945 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0028
# Epoch 89/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6942 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0028
# Epoch 90/100
# 3424/3424 [==============================] - 2s - loss: 0.0030 - acc: 0.6966 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0030 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0389 - val_mean_squared_error: 0.0029
# Epoch 91/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6948 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_acc: 0.6600 - val_mean_absolute_error: 0.0389 - val_mean_squared_error: 0.0029
# Epoch 92/100
# 3424/3424 [==============================] - 2s - loss: 0.0030 - acc: 0.6939 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0030 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0384 - val_mean_squared_error: 0.0028
# Epoch 93/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6968 - mean_absolute_error: 0.0403 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0028
# Epoch 94/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6945 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0028
# Epoch 95/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6954 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0028
# Epoch 96/100
# 3424/3424 [==============================] - 2s - loss: 0.0030 - acc: 0.6930 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0030 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0385 - val_mean_squared_error: 0.0028
# Epoch 97/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6928 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0028
# Epoch 98/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6986 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0385 - val_mean_squared_error: 0.0028
# Epoch 99/100
# 3424/3424 [==============================] - 2s - loss: 0.0031 - acc: 0.6951 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0387 - val_mean_squared_error: 0.0028
# Epoch 100/100
# 3424/3424 [==============================] - 2s - loss: 0.0030 - acc: 0.6948 - mean_absolute_error: 0.0399 - mean_squared_error: 0.0030 - val_loss: 0.0028 - val_acc: 0.6600 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0028
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
opt = 'Adamax'
epochs = 100
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train, y_train, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/100
# 1712/1712 [==============================] - 2s - loss: 0.0031 - acc: 0.7091 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0031 - val_loss: 0.0024 - val_acc: 0.7033 - val_mean_absolute_error: 0.0353 - val_mean_squared_error: 0.0024
# Epoch 2/100
# 1712/1712 [==============================] - 1s - loss: 0.0027 - acc: 0.7097 - mean_absolute_error: 0.0380 - mean_squared_error: 0.0027 - val_loss: 0.0024 - val_acc: 0.7033 - val_mean_absolute_error: 0.0353 - val_mean_squared_error: 0.0024
# Epoch 3/100
# 1712/1712 [==============================] - 1s - loss: 0.0026 - acc: 0.7062 - mean_absolute_error: 0.0367 - mean_squared_error: 0.0026 - val_loss: 0.0022 - val_acc: 0.7079 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0022
# Epoch 4/100
# 1712/1712 [==============================] - 1s - loss: 0.0024 - acc: 0.7261 - mean_absolute_error: 0.0357 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_acc: 0.7173 - val_mean_absolute_error: 0.0330 - val_mean_squared_error: 0.0021
# Epoch 5/100
# 1712/1712 [==============================] - 1s - loss: 0.0023 - acc: 0.7155 - mean_absolute_error: 0.0352 - mean_squared_error: 0.0023 - val_loss: 0.0020 - val_acc: 0.7196 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0020
# Epoch 6/100
# 1712/1712 [==============================] - 1s - loss: 0.0023 - acc: 0.7249 - mean_absolute_error: 0.0348 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_acc: 0.7336 - val_mean_absolute_error: 0.0306 - val_mean_squared_error: 0.0019
# Epoch 7/100
# 1712/1712 [==============================] - 1s - loss: 0.0022 - acc: 0.7249 - mean_absolute_error: 0.0338 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_acc: 0.7196 - val_mean_absolute_error: 0.0305 - val_mean_squared_error: 0.0018
# Epoch 8/100
# 1712/1712 [==============================] - 1s - loss: 0.0021 - acc: 0.7214 - mean_absolute_error: 0.0335 - mean_squared_error: 0.0021 - val_loss: 0.0019 - val_acc: 0.7243 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0019
# Epoch 9/100
# 1712/1712 [==============================] - 1s - loss: 0.0021 - acc: 0.7342 - mean_absolute_error: 0.0334 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_acc: 0.7290 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0017
# Epoch 10/100
# 1712/1712 [==============================] - 1s - loss: 0.0021 - acc: 0.7331 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_acc: 0.7266 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0017
# Epoch 11/100
# 1712/1712 [==============================] - 1s - loss: 0.0020 - acc: 0.7342 - mean_absolute_error: 0.0325 - mean_squared_error: 0.0020 - val_loss: 0.0016 - val_acc: 0.7290 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0016
# Epoch 12/100
# 1712/1712 [==============================] - 1s - loss: 0.0020 - acc: 0.7296 - mean_absolute_error: 0.0320 - mean_squared_error: 0.0020 - val_loss: 0.0017 - val_acc: 0.7266 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0017
# Epoch 13/100
# 1712/1712 [==============================] - 1s - loss: 0.0019 - acc: 0.7465 - mean_absolute_error: 0.0317 - mean_squared_error: 0.0019 - val_loss: 0.0016 - val_acc: 0.7126 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0016
# Epoch 14/100
# 1712/1712 [==============================] - 1s - loss: 0.0019 - acc: 0.7401 - mean_absolute_error: 0.0317 - mean_squared_error: 0.0019 - val_loss: 0.0015 - val_acc: 0.7477 - val_mean_absolute_error: 0.0278 - val_mean_squared_error: 0.0015
# Epoch 15/100
# 1712/1712 [==============================] - 1s - loss: 0.0019 - acc: 0.7488 - mean_absolute_error: 0.0316 - mean_squared_error: 0.0019 - val_loss: 0.0016 - val_acc: 0.7220 - val_mean_absolute_error: 0.0289 - val_mean_squared_error: 0.0016
# Epoch 16/100
# 1712/1712 [==============================] - 1s - loss: 0.0019 - acc: 0.7354 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0019 - val_loss: 0.0016 - val_acc: 0.7266 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0016
# Epoch 17/100
# 1712/1712 [==============================] - 1s - loss: 0.0019 - acc: 0.7442 - mean_absolute_error: 0.0313 - mean_squared_error: 0.0019 - val_loss: 0.0015 - val_acc: 0.7266 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0015
# Epoch 18/100
# 1712/1712 [==============================] - 1s - loss: 0.0018 - acc: 0.7377 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0018 - val_loss: 0.0014 - val_acc: 0.7266 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0014
# Epoch 19/100
# 1712/1712 [==============================] - 1s - loss: 0.0018 - acc: 0.7383 - mean_absolute_error: 0.0310 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_acc: 0.7290 - val_mean_absolute_error: 0.0283 - val_mean_squared_error: 0.0016
# Epoch 20/100
# 1712/1712 [==============================] - 1s - loss: 0.0018 - acc: 0.7371 - mean_absolute_error: 0.0307 - mean_squared_error: 0.0018 - val_loss: 0.0014 - val_acc: 0.7336 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0014
# Epoch 21/100
# 1712/1712 [==============================] - 1s - loss: 0.0018 - acc: 0.7436 - mean_absolute_error: 0.0305 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_acc: 0.7336 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0015
# Epoch 22/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7412 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0017 - val_loss: 0.0016 - val_acc: 0.7266 - val_mean_absolute_error: 0.0282 - val_mean_squared_error: 0.0016
# Epoch 23/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7465 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_acc: 0.7336 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0014
# Epoch 24/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7412 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_acc: 0.7266 - val_mean_absolute_error: 0.0272 - val_mean_squared_error: 0.0015
# Epoch 25/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7477 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_acc: 0.7360 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0014
# Epoch 26/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7564 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_acc: 0.7313 - val_mean_absolute_error: 0.0262 - val_mean_squared_error: 0.0014
# Epoch 27/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7465 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_acc: 0.7220 - val_mean_absolute_error: 0.0275 - val_mean_squared_error: 0.0015
# Epoch 28/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7494 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_acc: 0.7500 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0014
# Epoch 29/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7494 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_acc: 0.7547 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0014
# Epoch 30/100
# 1712/1712 [==============================] - 1s - loss: 0.0017 - acc: 0.7471 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_acc: 0.7383 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0014
# Epoch 31/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7523 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_acc: 0.7453 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0014
# Epoch 32/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7541 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_acc: 0.7453 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0014
# Epoch 33/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7512 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0016 - val_loss: 0.0015 - val_acc: 0.7313 - val_mean_absolute_error: 0.0274 - val_mean_squared_error: 0.0015
# Epoch 34/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7482 - mean_absolute_error: 0.0294 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_acc: 0.7243 - val_mean_absolute_error: 0.0268 - val_mean_squared_error: 0.0014
# Epoch 35/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7366 - mean_absolute_error: 0.0292 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7477 - val_mean_absolute_error: 0.0257 - val_mean_squared_error: 0.0013
# Epoch 36/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7535 - mean_absolute_error: 0.0295 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_acc: 0.7336 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0014
# Epoch 37/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7512 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7570 - val_mean_absolute_error: 0.0260 - val_mean_squared_error: 0.0013
# Epoch 38/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7564 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7266 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0013
# Epoch 39/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7506 - mean_absolute_error: 0.0293 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7593 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0013
# Epoch 40/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7599 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7477 - val_mean_absolute_error: 0.0252 - val_mean_squared_error: 0.0013
# Epoch 41/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7564 - mean_absolute_error: 0.0289 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7477 - val_mean_absolute_error: 0.0260 - val_mean_squared_error: 0.0013
# Epoch 42/100
# 1712/1712 [==============================] - 1s - loss: 0.0016 - acc: 0.7553 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7430 - val_mean_absolute_error: 0.0259 - val_mean_squared_error: 0.0013
# Epoch 43/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7629 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7290 - val_mean_absolute_error: 0.0257 - val_mean_squared_error: 0.0013
# Epoch 44/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7482 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7360 - val_mean_absolute_error: 0.0262 - val_mean_squared_error: 0.0013
# Epoch 45/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7634 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7664 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0013
# Epoch 46/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7477 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7523 - val_mean_absolute_error: 0.0249 - val_mean_squared_error: 0.0012
# Epoch 47/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7418 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7453 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0013
# Epoch 48/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7646 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7407 - val_mean_absolute_error: 0.0256 - val_mean_squared_error: 0.0013
# Epoch 49/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7564 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7430 - val_mean_absolute_error: 0.0251 - val_mean_squared_error: 0.0012
# Epoch 50/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7588 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7477 - val_mean_absolute_error: 0.0258 - val_mean_squared_error: 0.0013
# Epoch 51/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7582 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7664 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 52/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7535 - mean_absolute_error: 0.0284 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7664 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 53/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7640 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7570 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0012
# Epoch 54/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7558 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7453 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 0.0012
# Epoch 55/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7541 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7383 - val_mean_absolute_error: 0.0252 - val_mean_squared_error: 0.0013
# Epoch 56/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7547 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7407 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0013
# Epoch 57/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7430 - mean_absolute_error: 0.0284 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7453 - val_mean_absolute_error: 0.0251 - val_mean_squared_error: 0.0012
# Epoch 58/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7617 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7593 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0012
# Epoch 59/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7482 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_acc: 0.7617 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0013
# Epoch 60/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7588 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7570 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 61/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7494 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7453 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0012
# Epoch 62/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7535 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7477 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0012
# Epoch 63/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7599 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7430 - val_mean_absolute_error: 0.0251 - val_mean_squared_error: 0.0012
# Epoch 64/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7605 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7687 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# Epoch 65/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7564 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7523 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0012
# Epoch 66/100
# 1712/1712 [==============================] - 1s - loss: 0.0015 - acc: 0.7535 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 67/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7593 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7687 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 68/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7529 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_acc: 0.7570 - val_mean_absolute_error: 0.0253 - val_mean_squared_error: 0.0013
# Epoch 69/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7588 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7593 - val_mean_absolute_error: 0.0249 - val_mean_squared_error: 0.0012
# Epoch 70/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7453 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7523 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0012
# Epoch 71/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7693 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7593 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# Epoch 72/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7652 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0249 - val_mean_squared_error: 0.0012
# Epoch 73/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7716 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_acc: 0.7360 - val_mean_absolute_error: 0.0256 - val_mean_squared_error: 0.0013
# Epoch 74/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7611 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7453 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0012
# Epoch 75/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7611 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7687 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0012
# Epoch 76/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7675 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7593 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0012
# Epoch 77/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7547 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7664 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# Epoch 78/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7646 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0012
# Epoch 79/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7634 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7640 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# Epoch 80/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7629 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7804 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 81/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7541 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0012
# Epoch 82/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7710 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0012
# Epoch 83/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7775 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7593 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0012
# Epoch 84/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7617 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7664 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# Epoch 85/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7640 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 0.0012
# Epoch 86/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7722 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7687 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0011
# Epoch 87/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7693 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7617 - val_mean_absolute_error: 0.0240 - val_mean_squared_error: 0.0011
# Epoch 88/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7693 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0012
# Epoch 89/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7634 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# Epoch 90/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7652 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7570 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 0.0012
# Epoch 91/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7623 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7617 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 0.0012
# Epoch 92/100
# 1712/1712 [==============================] - 1s - loss: 0.0013 - acc: 0.7734 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_acc: 0.7734 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 93/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7763 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7570 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0012
# Epoch 94/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7658 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_acc: 0.7593 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012
# Epoch 95/100
# 1712/1712 [==============================] - 1s - loss: 0.0013 - acc: 0.7845 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7687 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 96/100
# 1712/1712 [==============================] - 1s - loss: 0.0013 - acc: 0.7693 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7710 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0011
# Epoch 97/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7751 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7687 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 98/100
# 1712/1712 [==============================] - 1s - loss: 0.0013 - acc: 0.7845 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7593 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0011
# Epoch 99/100
# 1712/1712 [==============================] - 1s - loss: 0.0014 - acc: 0.7640 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7500 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0011
# Epoch 100/100
# 1712/1712 [==============================] - 1s - loss: 0.0013 - acc: 0.7699 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_acc: 0.7523 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0012
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
opt = 'Adamax'
epochs = 100
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train_all, y_train_all, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/100
# 3424/3424 [==============================] - 3s - loss: 0.0016 - acc: 0.7491 - mean_absolute_error: 0.0294 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_acc: 0.7629 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0014
# Epoch 2/100
# 3424/3424 [==============================] - 2s - loss: 0.0016 - acc: 0.7491 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_acc: 0.7699 - val_mean_absolute_error: 0.0257 - val_mean_squared_error: 0.0013
# Epoch 3/100
# 3424/3424 [==============================] - 2s - loss: 0.0016 - acc: 0.7485 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0016 - val_loss: 0.0011 - val_acc: 0.7804 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0011
# Epoch 4/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7564 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7710 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 0.0012
# Epoch 5/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7468 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7710 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0012
# Epoch 6/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7500 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0015 - val_loss: 0.0011 - val_acc: 0.7757 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0011
# Epoch 7/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7596 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7687 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 0.0012
# Epoch 8/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7512 - mean_absolute_error: 0.0284 - mean_squared_error: 0.0015 - val_loss: 0.0011 - val_acc: 0.7862 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0011
# Epoch 9/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7593 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0011 - val_acc: 0.7897 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 10/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7596 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7722 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0012
# Epoch 11/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7631 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7687 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 0.0012
# Epoch 12/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7658 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_acc: 0.7699 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0012
# Epoch 13/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7567 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 0.0011 - val_acc: 0.7734 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0011
# Epoch 14/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7596 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7827 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0011
# Epoch 15/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7629 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7921 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 16/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7704 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0015 - val_loss: 0.0011 - val_acc: 0.8049 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 17/100
# 3424/3424 [==============================] - 2s - loss: 0.0015 - acc: 0.7602 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 0.0011 - val_acc: 0.7967 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 18/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7649 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7991 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 19/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7617 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.8037 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 20/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7602 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7909 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 21/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7664 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7757 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0011
# Epoch 22/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7634 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.8014 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 23/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7681 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7874 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0011
# Epoch 24/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7742 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7827 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 25/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7643 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7780 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 26/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7602 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7839 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 27/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7661 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7815 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 28/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7605 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7722 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011
# Epoch 29/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7731 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7991 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0011
# Epoch 30/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7599 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7991 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0011
# Epoch 31/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7655 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7967 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 32/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7614 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7921 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 33/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7631 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7815 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 34/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7666 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 35/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7684 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 9.8889e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8889e-04
# Epoch 36/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7640 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.8084 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011
# Epoch 37/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7634 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7944 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 38/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7719 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7967 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 39/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7775 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8049 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 40/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7675 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7804 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011
# Epoch 41/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7661 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7944 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 42/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7742 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7921 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 43/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7722 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7979 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 44/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7596 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 45/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7763 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7967 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 46/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7678 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 47/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7731 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7886 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 48/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7754 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7886 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 49/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7655 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7839 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 50/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7634 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7979 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011
# Epoch 51/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7664 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7897 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 52/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7731 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 9.9576e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9576e-04
# Epoch 53/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7681 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.8026 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011
# Epoch 54/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7687 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7991 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 55/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7734 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7944 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 56/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7652 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 57/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7614 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 58/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7661 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7850 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0010
# Epoch 59/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7716 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 60/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7655 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 9.7276e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7276e-04
# Epoch 61/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7713 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7897 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 62/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7699 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7991 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 63/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7713 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 9.7348e-04 - val_acc: 0.7944 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7348e-04
# Epoch 64/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7754 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 9.8597e-04 - val_acc: 0.7909 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8597e-04
# Epoch 65/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7681 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.9155e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.9155e-04
# Epoch 66/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7664 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8107 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 67/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7710 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 9.5959e-04 - val_acc: 0.7979 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5959e-04
# Epoch 68/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7704 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.8604e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8604e-04
# Epoch 69/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7760 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7827 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 70/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7745 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8037 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 71/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7617 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7921 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 72/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7731 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 9.5642e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5642e-04
# Epoch 73/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7739 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7921 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 74/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7783 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7886 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 75/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7669 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 9.7512e-04 - val_acc: 0.8014 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7512e-04
# Epoch 76/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7748 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7839 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 77/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7731 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.4586e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.4586e-04
# Epoch 78/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7678 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.8839e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8839e-04
# Epoch 79/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7769 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 80/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7798 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.9341e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9341e-04
# Epoch 81/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7751 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7979 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 82/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.6568e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.6568e-04
# Epoch 83/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7780 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7710 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 84/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7716 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.8741e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8741e-04
# Epoch 85/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7748 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7956 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 86/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7678 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 9.9186e-04 - val_acc: 0.8014 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9186e-04
# Epoch 87/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7763 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.7176e-04 - val_acc: 0.8002 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7176e-04
# Epoch 88/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7818 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.8095e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8095e-04
# Epoch 89/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7748 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7909 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 90/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7666 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7827 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 91/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7681 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7991 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 92/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7719 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.6545e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6545e-04
# Epoch 93/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7944 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 94/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7780 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7886 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 95/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7643 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.2814e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0217 - val_mean_squared_error: 9.2814e-04
# Epoch 96/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7766 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.9944e-04 - val_acc: 0.8061 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9944e-04
# Epoch 97/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7745 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.6831e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6831e-04
# Epoch 98/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7739 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7909 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 99/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7842 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.9219e-04 - val_acc: 0.7932 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9219e-04
# Epoch 100/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.7621e-04 - val_acc: 0.7909 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7621e-04
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
opt = 'Adam'
epochs = 100
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train_all, y_train_all, validation_split=0.2, epochs=epochs)
show_history_graph(hist)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/100
# 3424/3424 [==============================] - 3s - loss: 0.0014 - acc: 0.7757 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7745 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 2/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7830 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7827 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 3/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7757 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7897 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 4/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7716 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7780 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 5/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7664 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7815 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 6/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7739 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7956 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 7/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7707 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 8/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7693 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7944 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 9/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7745 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 10/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7704 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7617 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 11/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7810 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7734 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 12/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7707 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7979 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 13/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7722 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 14/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7725 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7839 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 15/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7772 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7991 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 16/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7731 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7932 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011
# Epoch 17/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7675 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8131 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 18/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7666 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010 acc: 0.7673 - mean_absolute_error: 0.0272 - mean_squared_error: 0.
# Epoch 19/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7702 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7979 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 20/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7737 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 9.7367e-04 - val_acc: 0.7932 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7367e-04
# Epoch 21/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7775 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 9.9249e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9249e-04
# Epoch 22/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7637 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 9.8921e-04 - val_acc: 0.7979 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8921e-04
# Epoch 23/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7751 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.7792 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 24/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7763 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.7303e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.7303e-04
# Epoch 25/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7722 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_acc: 0.7897 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011te_error: 0.0271 - mean_squared
# Epoch 26/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7637 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 9.9524e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9524e-04
# Epoch 27/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7702 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 9.6981e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.6981e-04
# Epoch 28/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7693 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8119 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 29/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7655 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8143 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 30/100
# 3424/3424 [==============================] - 2s - loss: 0.0014 - acc: 0.7687 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 31/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7783 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 32/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7763 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7687 - val_mean_absolute_error: 0.0239 - val_mean_squared_error: 0.0011
# Epoch 33/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7742 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 9.6064e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6064e-04
# Epoch 34/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7731 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7500 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0011
# Epoch 35/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7763 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.9640e-04 - val_acc: 0.7956 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.9640e-04
# Epoch 36/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7763 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7640 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 37/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7634 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - val_loss: 9.8706e-04 - val_acc: 0.7932 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.8706e-04
# Epoch 38/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7725 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 39/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7795 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8026 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.001013 - acc: 0.7786 - mean_absolute_error: 0.0269 - mean_squared_error: 0.00
# Epoch 40/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7704 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7886 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 41/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7704 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7921 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 42/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7728 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7687 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 43/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7798 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8131 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 44/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.5934e-04 - val_acc: 0.8248 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.5934e-04
# Epoch 45/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7754 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.6988e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.6988e-04
# Epoch 46/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7702 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.9008e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.9008e-04
# Epoch 47/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7754 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7769 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 48/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7789 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 49/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7754 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7769 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 0.0011
# Epoch 50/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7792 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7687 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 51/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7707 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8037 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 52/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7722 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7967 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.001056 - mean_absolute_error: 0.0268 - mean_squared_err
# Epoch 53/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7991 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 54/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7760 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.8629e-04 - val_acc: 0.7862 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8629e-04
# Epoch 55/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7702 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.2921e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0217 - val_mean_squared_error: 9.2921e-04
# Epoch 56/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7836 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 9.8188e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8188e-04
# Epoch 57/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7780 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7991 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 0.0010
# Epoch 58/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7728 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 59/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7693 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8037 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010 acc: 0.7779 - mean_absolute_error: 0.0268 - mean_squared_err - ETA: 1s - loss: 0.0013 - acc: 0.7761 - mean_absolute_error: 0.0
# Epoch 60/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7766 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 9.6928e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.6928e-04
# Epoch 61/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7810 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.8108e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8108e-04
# Epoch 62/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7748 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.8389e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8389e-04
# Epoch 63/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7731 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7932 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 64/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7801 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.7999e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7999e-04
# Epoch 65/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7786 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.6894e-04 - val_acc: 0.8224 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6894e-04
# Epoch 66/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7827 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.7597e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7597e-04
# Epoch 67/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7880 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.5714e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.5714e-04
# Epoch 68/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7871 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8026 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 69/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7757 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 70/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7833 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.9073e-04 - val_acc: 0.7956 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.9073e-04
# Epoch 71/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7839 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.4079e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 9.4079e-04
# Epoch 72/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7751 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.6205e-04 - val_acc: 0.8224 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.6205e-04
# Epoch 73/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7777 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.6631e-04 - val_acc: 0.7932 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.6631e-04
# Epoch 74/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7827 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 75/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7833 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.8308e-04 - val_acc: 0.7956 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8308e-04
# Epoch 76/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7766 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 77/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7853 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.7429e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7429e-04
# Epoch 78/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7886 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8154 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 79/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7836 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.9964e-04 - val_acc: 0.8131 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9964e-04
# Epoch 80/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7739 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8049 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 81/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7795 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.8096 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0011
# Epoch 82/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7754 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7804 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 83/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7807 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.8096 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 84/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7830 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.8428e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8428e-04n_absolute_error: 0.026
# Epoch 85/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.8656e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8656e-04
# Epoch 86/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7792 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.8799e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8799e-04
# Epoch 87/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7777 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.8761e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.8761e-04absolute_error: 0.026
# Epoch 88/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7789 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8049 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 89/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7775 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 9.5363e-04 - val_acc: 0.8166 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5363e-04
# Epoch 90/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7731 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 9.9782e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9782e-04
# Epoch 91/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7693 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.7781e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7781e-04
# Epoch 92/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7850 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7839 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 93/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7754 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7839 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 94/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7856 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7967 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 95/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7775 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.8167e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8167e-04
# Epoch 96/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7745 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.6250e-04 - val_acc: 0.7792 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6250e-04rror: 0.0264 - mean_s
# Epoch 97/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7853 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7769 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 98/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7947 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8213 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 99/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8154 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 100/100
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7801 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.9060e-04 - val_acc: 0.8213 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9060e-04
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %%
# looks like Adamax is still the winner over SGD + Nesterov and using augemented data has improved the validation
# accuracy by almost 4% over the non augmented data to val_acc: 0.7909
# However Adam seems to get slightly better validation accuracy at val_acc: 0.8213
# so lets give it a try on a longer run

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
opt = 'Adam'
epochs = 300
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=0, mode='auto')
model_file = './model5_adam_long.hdf5'
checkpointer = ModelCheckpoint(filepath=model_file, verbose=0, save_best_only=True)
model5.compile(loss='mean_squared_error', optimizer=opt, metrics=['acc', 'mae', 'mse'])
hist = model5.fit(X_train_all, y_train_all, validation_split=0.2, epochs=epochs, callbacks=[early, checkpointer], shuffle=True)
show_history_graph(hist)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/300
# 3424/3424 [==============================] - 5s - loss: 0.0013 - acc: 0.7891 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 9.5058e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 9.5058e-04
# Epoch 2/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7783 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8143 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 3/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7868 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.8754e-04 - val_acc: 0.8014 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8754e-04
# Epoch 4/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7792 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.8072 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0011
# Epoch 5/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7719 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.8120e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8120e-04
# Epoch 6/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7739 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.9178e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9178e-04
# Epoch 7/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7830 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7839 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 8/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7815 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.9021e-04 - val_acc: 0.7897 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9021e-04
# Epoch 9/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7763 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.3298e-04 - val_acc: 0.8143 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 9.3298e-04
# Epoch 10/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7722 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.6171e-04 - val_acc: 0.8189 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.6171e-04
# Epoch 11/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7833 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.7372e-04 - val_acc: 0.8224 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.7372e-04
# Epoch 12/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7842 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.6298e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6298e-04
# Epoch 13/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7748 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.6559e-04 - val_acc: 0.8002 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6559e-04
# Epoch 14/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7807 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 15/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7754 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.9277e-04 - val_acc: 0.8154 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9277e-04
# Epoch 16/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7792 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.8441e-04 - val_acc: 0.8154 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8441e-04
# Epoch 17/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7801 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.8423e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8423e-04
# Epoch 18/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7821 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.8957e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8957e-04
# Epoch 19/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7883 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.5380e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5380e-04
# Epoch 20/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7862 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8166 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 21/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7818 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8026 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 22/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7842 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7956 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 23/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7801 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.3912e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 9.3912e-04
# Epoch 24/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7783 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.9344e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9344e-04
# Epoch 25/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7897 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.5639e-04 - val_acc: 0.8189 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.5639e-04
# Epoch 26/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7795 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 9.9207e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9207e-04
# Epoch 27/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7883 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8072 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 28/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7699 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.6381e-04 - val_acc: 0.7862 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.6381e-04
# Epoch 29/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7871 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.7841e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7841e-04
# Epoch 30/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7827 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.9791e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9791e-04
# Epoch 31/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7821 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7956 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 32/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7868 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.6523e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6523e-04
# Epoch 33/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7900 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8107 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 34/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7903 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.5196e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.5196e-04
# Epoch 35/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7845 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7792 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 36/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7827 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.9390e-04 - val_acc: 0.7979 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9390e-04
# Epoch 37/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7894 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7710 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0011
# Epoch 38/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7742 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8131 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 39/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7824 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7883e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7883e-04
# Epoch 40/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7681 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.6179e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6179e-04
# Epoch 41/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7789 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.6109e-04 - val_acc: 0.8014 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6109e-04
# Epoch 42/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7777 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.7754e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7754e-04
# Epoch 43/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7883 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.3213e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 9.3213e-04
# Epoch 44/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7821 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.9635e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9635e-04
# Epoch 45/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7801 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.8026 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 46/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7900 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.7331e-04 - val_acc: 0.8143 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7331e-04
# Epoch 47/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7929 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8084 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 48/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7903 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.6464e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 9.6464e-04
# Epoch 49/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7772 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8049 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 50/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7868 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7534e-04 - val_acc: 0.8178 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7534e-04
# Epoch 51/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7888 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7874 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 52/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7853 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.9608e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9608e-04
# Epoch 53/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7810 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.8002 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 54/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7845 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.8962e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8962e-04
# Epoch 55/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7973 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.9756e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9756e-04
# Epoch 56/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7856 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.7249e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7249e-04
# Epoch 57/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7815 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.6866e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6866e-04
# Epoch 58/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7897 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.7570e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7570e-04
# Epoch 59/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7821 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.5924e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5924e-04
# Epoch 60/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7850 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.7739e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7739e-04
# Epoch 61/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7818 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8107 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 62/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7906 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7317e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7317e-04
# Epoch 63/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7815 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.2976e-04 - val_acc: 0.8014 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 9.2976e-04
# Epoch 64/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7842 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.9654e-04 - val_acc: 0.8061 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.9654e-04
# Epoch 65/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7848 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7909 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 66/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7801 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.6318e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6318e-04
# Epoch 67/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7824 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.9396e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9396e-04
# Epoch 68/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7897 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7979 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 69/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7707 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8189 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 70/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7699 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 71/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7769 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.8944e-04 - val_acc: 0.7944 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8944e-04
# Epoch 72/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7719 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7850 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 73/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.8647e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8647e-04
# Epoch 74/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7798 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7991 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 75/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7932 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 0.0010
# Epoch 76/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7839 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.5984e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.5984e-04
# Epoch 77/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7836 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8143 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 78/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7807 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8072 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 79/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7880 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7956 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 80/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.8049 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 0.0011
# Epoch 81/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7798 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.8778e-04 - val_acc: 0.8166 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.8778e-04
# Epoch 82/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7912 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.9925e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9925e-04
# Epoch 83/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7815 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.8626e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8626e-04
# Epoch 84/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7906 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 85/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7848 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 86/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7871 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.6470e-04 - val_acc: 0.7862 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6470e-04
# Epoch 87/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7836 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.6135e-04 - val_acc: 0.8224 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6135e-04
# Epoch 88/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7848 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.0982e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 9.0982e-04
# Epoch 89/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7923 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.7721e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7721e-04
# Epoch 90/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7830 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.5277e-04 - val_acc: 0.8131 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.5277e-04
# Epoch 91/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7921 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.8103e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.8103e-04
# Epoch 92/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7888 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7413e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7413e-04
# Epoch 93/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7859 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7840e-04 - val_acc: 0.7862 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7840e-04
# Epoch 94/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7880 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.5370e-04 - val_acc: 0.7956 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5370e-04
# Epoch 95/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7926 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7917e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7917e-04
# Epoch 96/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7848 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.8057e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8057e-04
# Epoch 97/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7827 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8166 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 98/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7915 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.7125e-04 - val_acc: 0.8154 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7125e-04
# Epoch 99/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7859 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 100/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7856 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7956 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 101/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7888 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.9513e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9513e-04
# Epoch 102/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7745 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8084 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 103/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7845 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_acc: 0.8318 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0011
# Epoch 104/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7891 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7909 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 105/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7941 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8131 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 106/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7769 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.8194e-04 - val_acc: 0.7967 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8194e-04
# Epoch 107/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7921 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.6341e-04 - val_acc: 0.8143 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6341e-04
# Epoch 108/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7836 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8259 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 109/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.6179e-04 - val_acc: 0.8014 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.6179e-04
# Epoch 110/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7827 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.6515e-04 - val_acc: 0.8189 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 9.6515e-04
# Epoch 111/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7886 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.5938e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.5938e-04
# Epoch 112/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7871 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7909 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 113/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7915 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.8893e-04 - val_acc: 0.8166 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8893e-04
# Epoch 114/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7789 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.8702e-04 - val_acc: 0.8201 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8702e-04
# Epoch 115/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7839 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.9872e-04 - val_acc: 0.7944 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9872e-04
# Epoch 116/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 9.7797e-04 - val_acc: 0.7932 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7797e-04
# Epoch 117/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7944 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.8947e-04 - val_acc: 0.7979 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.8947e-04
# Epoch 118/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7877 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 0.0010
# Epoch 119/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7918 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.6929e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6929e-04
# Epoch 120/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7871 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8224 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 121/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7827 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.8694e-04 - val_acc: 0.7944 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8694e-04
# Epoch 122/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7886 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.8223e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8223e-04
# Epoch 123/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7909 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7991 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 124/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7874 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0013 - val_loss: 9.8541e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8541e-04
# Epoch 125/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7827 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8037 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 126/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7830 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7944 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 0.0010
# Epoch 127/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7719 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.6928e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6928e-04
# Epoch 128/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7877 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8026 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 129/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7842 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.6068e-04 - val_acc: 0.8201 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.6068e-04
# Epoch 130/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7830 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.8850e-04 - val_acc: 0.8143 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8850e-04
# Epoch 131/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7880 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8189 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0010
# Epoch 132/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7850 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.6404e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6404e-04
# Epoch 133/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7824 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.6969e-04 - val_acc: 0.8178 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6969e-04
# Epoch 134/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7739 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.7609e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.7609e-04
# Epoch 135/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7798 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 9.6326e-04 - val_acc: 0.8096 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 9.6326e-04
# Epoch 136/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7836 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.7886 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 137/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7839 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7945e-04 - val_acc: 0.8224 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.7945e-04
# Epoch 138/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7868 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7874 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 139/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7915 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.9860e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9860e-04
# Epoch 140/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7769 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8026 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 141/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7865 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.9208e-04 - val_acc: 0.8189 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9208e-04
# Epoch 142/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7833 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 9.8357e-04 - val_acc: 0.8026 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.8357e-04
# Epoch 143/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7821 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7792 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0010
# Epoch 144/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7850 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8084 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 145/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7842 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8049 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 0.0010
# Epoch 146/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7921 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_acc: 0.7909 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 0.0011
# Epoch 147/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7839 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_acc: 0.7850 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0011
# Epoch 148/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7912 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0013 - val_loss: 9.3888e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 9.3888e-04
# Epoch 149/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7886 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.6986e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6986e-04
# Epoch 150/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7839 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7921 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 151/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7842 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.6837e-04 - val_acc: 0.7979 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.6837e-04
# Epoch 152/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7842 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 9.9565e-04 - val_acc: 0.7991 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.9565e-04
# Epoch 153/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7900 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8049 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 154/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.8017 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7967 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 155/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7772 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.9703e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9703e-04
# Epoch 156/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7848 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.9455e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 9.9455e-04
# Epoch 157/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7891 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.9052e-04 - val_acc: 0.8037 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.9052e-04
# Epoch 158/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7903 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.7100e-04 - val_acc: 0.8107 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7100e-04
# Epoch 159/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7812 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.9236e-04 - val_acc: 0.7886 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 9.9236e-04
# Epoch 160/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7777 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8189 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 161/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7923 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_acc: 0.7839 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0011
# Epoch 162/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7877 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7815 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 163/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7777 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 164/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7783 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7897 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 165/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7877 - mean_absolute_error: 0.0257 - mean_squared_error: 0.0012 - val_loss: 9.8472e-04 - val_acc: 0.8119 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.8472e-04
# Epoch 166/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7891 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 167/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7859 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 9.7370e-04 - val_acc: 0.7897 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7370e-04
# Epoch 168/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7839 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 169/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7827 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8201 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 170/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7815 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.5318e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 9.5318e-04
# Epoch 171/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7877 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0012 - val_loss: 9.7054e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7054e-04
# Epoch 172/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7891 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7994e-04 - val_acc: 0.8201 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.7994e-04
# Epoch 173/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7801 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7522e-04 - val_acc: 0.8259 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.7522e-04
# Epoch 174/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7760 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8037 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 175/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7804 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8014 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 176/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7853 - mean_absolute_error: 0.0257 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7815 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 177/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7821 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8072 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010
# Epoch 178/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7859 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.8178e-04 - val_acc: 0.8049 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.8178e-04
# Epoch 179/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7862 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7967 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 180/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7842 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.7874 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 181/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7833 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0010
# Epoch 182/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7798 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8061 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0010
# Epoch 183/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7944 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - val_loss: 9.7911e-04 - val_acc: 0.8072 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7911e-04
# Epoch 184/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7862 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.3620e-04 - val_acc: 0.8131 - val_mean_absolute_error: 0.0217 - val_mean_squared_error: 9.3620e-04
# Epoch 185/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7874 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8096 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 186/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7894 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.4177e-04 - val_acc: 0.8084 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 9.4177e-04
# Epoch 187/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7999 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_acc: 0.8002 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 0.0010
# Epoch 188/300
# 3424/3424 [==============================] - 2s - loss: 0.0012 - acc: 0.7880 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 9.7555e-04 - val_acc: 0.8002 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.7555e-04
# Epoch 189/300
# 3424/3424 [==============================] - 2s - loss: 0.0013 - acc: 0.7947 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_acc: 0.8119 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 0.0010
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %% [markdown]
# ---
# <a id='step7'></a>
#
# ## Step 7: Visualize the Loss and Test Predictions

# %% [markdown]
# ### (IMPLEMENTATION)  Answer a few questions and visualize the loss
#
# __Question 1:__ Outline the steps you took to get to your final neural network architecture and your reasoning at each step.
#
# __Answer:__
#
#
# __Question 2:__ Defend your choice of optimizer.  Which optimizers did you test, and how did you determine which worked best?
#
# __Answer:__
#
#
# Use the code cell below to plot the training and validation loss of your neural network.  You may find [this resource](http://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/) useful.

# %%
## TODO: Visualize the training and validation loss of your neural network
show_history_graph(hist)
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_mean_absolute_error', 'val_mean_squared_error', 'loss', 'acc', 'mean_absolute_error', 'mean_squared_error'])

# %% [markdown]
# __Question 3:__  Do you notice any evidence of overfitting or underfitting in the above plot?  If so, what steps have you taken to improve your model?  Note that slight overfitting or underfitting will not hurt your chances of a successful submission, as long as you have attempted some solutions towards improving your model (such as _regularization, dropout, increased/decreased number of layers, etc_).
#
# __Answer:__

# %% [markdown]
# ### Visualize a Subset of the Test Predictions
#
# Execute the code cell below to visualize your model's predicted keypoints on a subset of the testing images.

# %%
y_test = model5.predict(X_test)
fig = plt.figure(figsize=(20,20))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1, xticks=[], yticks=[])
    plot_data(X_test[i], y_test[i], ax)

# %% [markdown]
# ---
# <a id='step8'></a>
#
# ## Step 8: Complete the pipeline
#
# With the work you did in Sections 1 and 2 of this notebook, along with your freshly trained facial keypoint detector, you can now complete the full pipeline.  That is given a color image containing a person or persons you can now
#
# - Detect the faces in this image automatically using OpenCV
# - Predict the facial keypoints in each face detected in the image
# - Paint predicted keypoints on each face detected
#
# In this Subsection you will do just this!

# %% [markdown]
# ### (IMPLEMENTATION) Facial Keypoints Detector
#
# Use the OpenCV face detection functionality you built in previous Sections to expand the functionality of your keypoints detector to color images with arbitrary size.  Your function should perform the following steps
#
# 1. Accept a color image.
# 2. Convert the image to grayscale.
# 3. Detect and crop the face contained in the image.
# 4. Locate the facial keypoints in the cropped image.
# 5. Overlay the facial keypoints in the original (color, uncropped) image.
#
# **Note**: step 4 can be the trickiest because remember your convolutional network is only trained to detect facial keypoints in $96 \times 96$ grayscale images where each pixel was normalized to lie in the interval $[0,1]$, and remember that each facial keypoint was normalized during training to the interval $[-1,1]$.  This means - practically speaking - to paint detected keypoints onto a test face you need to perform this same pre-processing to your candidate face  - that is after detecting it you should resize it to $96 \times 96$ and normalize its values before feeding it into your facial keypoint detector.  To be shown correctly on the original image the output keypoints from your detector then need to be shifted and re-normalized from the interval $[-1,1]$ to the width and height of your detected face.
#
# When complete you should be able to produce example images like the one below
#
# <img src="images/obamas_with_keypoints.png" width=1000 height=1000/>

# %%
# reload model
final_model = Sequential()
final_model.add(Convolution2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(96, 96, 1)))
final_model.add(MaxPooling2D(pool_size=(2, 2)))
final_model.add(Dropout(0.1))

final_model.add(Convolution2D(filters=32, kernel_size=(2, 2), activation='relu'))
final_model.add(MaxPooling2D(pool_size=(2, 2)))
final_model.add(Dropout(0.2))

final_model.add(Convolution2D(filters=64, kernel_size=(2, 2), activation='relu'))
final_model.add(MaxPooling2D(pool_size=(2, 2)))
final_model.add(Dropout(0.3))

final_model.add(Flatten())
final_model.add(Dense(256, activation='relu'))
final_model.add(Dropout(0.5))
final_model.add(Dense(30))

# Summarize the model
final_model.summary()

final_model_file = './model5_adam_long.hdf5'
final_model.load_weights(final_model_file)

# %%
# Load in color image for face detection
image = cv2.imread('images/obamas4.jpg')


# Convert the image to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


# plot our image
fig = plt.figure(figsize = (9,9))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title('image copy')
ax1.imshow(image_copy)

# %%
### TODO: Use the face detection code we saw in Section 1 with your trained conv-net 
## TODO : Paint the predicted keypoints on the test image

# %% [markdown]
# ### (Optional) Further Directions - add a filter using facial keypoints to your laptop camera
#
# Now you can add facial keypoint detection to your laptop camera - as illustrated in the gif below.
#
# <img src="images/facial_keypoint_test.gif" width=400 height=300/>
#
# The next Python cell contains the basic laptop video camera function used in the previous optional video exercises.  Combine it with the functionality you developed for keypoint detection and marking in the previous exercise and you should be good to go!

# %%
import cv2
import time 
from keras.models import load_model
def laptop_camera_go():
    # Create instance of video capturer
    cv2.namedWindow("face detection activated")
    vc = cv2.VideoCapture(0)

    # Try to get the first frame
    if vc.isOpened(): 
        rval, frame = vc.read()
    else:
        rval = False
    
    # keep video stream open
    while rval:
        # plot image from camera with detections marked
        cv2.imshow("face detection activated", frame)
        
        # exit functionality - press any key to exit laptop video
        key = cv2.waitKey(20)
        if key > 0: # exit by pressing any key
            # destroy windows
            cv2.destroyAllWindows()
            
            # hack from stack overflow for making sure window closes on osx --> https://stackoverflow.com/questions/6116564/destroywindow-does-not-close-window-on-mac-using-python-and-opencv
            for i in range (1,5):
                cv2.waitKey(1)
            return
        
        # read next frame
        time.sleep(0.05)             # control framerate for computation - default 20 frames per sec
        rval, frame = vc.read()

# %%
# Run your keypoint face painter
laptop_camera_go()

# %% [markdown]
# ### (Optional) Further Directions - add a filter using facial keypoints
#
# Using your freshly minted facial keypoint detector pipeline you can now do things like add fun filters to a person's face automatically.  In this optional exercise you can play around with adding sunglasses automatically to each individual's face in an image as shown in a demonstration image below.
#
# <img src="images/obamas_with_shades.png" width=1000 height=1000/>
#
# To produce this effect an image of a pair of sunglasses shown in the Python cell below.

# %%
# Load in sunglasses image - note the usage of the special option
# cv2.IMREAD_UNCHANGED, this option is used because the sunglasses 
# image has a 4th channel that allows us to control how transparent each pixel in the image is
sunglasses = cv2.imread("images/sunglasses_4.png", cv2.IMREAD_UNCHANGED)

# Plot the image
fig = plt.figure(figsize = (6,6))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(sunglasses)
ax1.axis('off');

# %% [markdown]
# This image is placed over each individual's face using the detected eye points to determine the location of the sunglasses, and eyebrow points to determine the size that the sunglasses should be for each person (one could also use the nose point to determine this).
#
# Notice that this image actually has *4 channels*, not just 3.

# %%
# Print out the shape of the sunglasses image
print ('The sunglasses image has shape: ' + str(np.shape(sunglasses)))

# %% [markdown]
# It has the usual red, blue, and green channels any color image has, with the 4th channel representing the transparency level of each pixel in the image.  Here's how the transparency channel works: the lower the value, the more transparent the pixel will become.  The lower bound (completely transparent) is zero here, so any pixels set to 0 will not be seen.
#
# This is how we can place this image of sunglasses on someone's face and still see the area around of their face where the sunglasses lie - because these pixels in the sunglasses image have been made completely transparent.
#
# Lets check out the alpha channel of our sunglasses image in the next Python cell.  Note because many of the pixels near the boundary are transparent we'll need to explicitly print out non-zero values if we want to see them.

# %%
# Print out the sunglasses transparency (alpha) channel
alpha_channel = sunglasses[:,:,3]
print ('the alpha channel here looks like')
print (alpha_channel)

# Just to double check that there are indeed non-zero values
# Let's find and print out every value greater than zero
values = np.where(alpha_channel != 0)
print ('\n the non-zero values of the alpha channel look like')
print (values)

# %% [markdown]
# This means that when we place this sunglasses image on top of another image, we can use the transparency channel as a filter to tell us which pixels to overlay on a new image (only the non-transparent ones with values greater than zero).
#
# One last thing: it's helpful to understand which keypoint belongs to the eyes, mouth, etc. So, in the image below, we also display the index of each facial keypoint directly on the image so that you can tell which keypoints are for the eyes, eyebrows, etc.
#
# <img src="images/obamas_points_numbered.png" width=500 height=500/>
#
# With this information, you're well on your way to completing this filtering task!  See if you can place the sunglasses automatically on the individuals in the image loaded in / shown in the next Python cell.

# %%
# Load in color image for face detection
image = cv2.imread('images/obamas4.jpg')

# Convert the image to RGB colorspace
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


# Plot the image
fig = plt.figure(figsize = (8,8))
ax1 = fig.add_subplot(111)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title('Original Image')
ax1.imshow(image)

# %%
## (Optional) TODO: Use the face detection code we saw in Section 1 with your trained conv-net to put
## sunglasses on the individuals in our test image

# %% [markdown]
# ###  (Optional) Further Directions - add a filter using facial keypoints to your laptop camera
#
# Now you can add the sunglasses filter to your laptop camera - as illustrated in the gif below.
#
# <img src="images/mr_sunglasses.gif" width=250 height=250/>
#
# The next Python cell contains the basic laptop video camera function used in the previous optional video exercises.  Combine it with the functionality you developed for adding sunglasses to someone's face in the previous optional exercise and you should be good to go!

# %%
import cv2
import time 
from keras.models import load_model
import numpy as np

def laptop_camera_go():
    # Create instance of video capturer
    cv2.namedWindow("face detection activated")
    vc = cv2.VideoCapture(0)

    # try to get the first frame
    if vc.isOpened(): 
        rval, frame = vc.read()
    else:
        rval = False
    
    # Keep video stream open
    while rval:
        # Plot image from camera with detections marked
        cv2.imshow("face detection activated", frame)
        
        # Exit functionality - press any key to exit laptop video
        key = cv2.waitKey(20)
        if key > 0: # exit by pressing any key
            # Destroy windows 
            cv2.destroyAllWindows()
            
            for i in range (1,5):
                cv2.waitKey(1)
            return
        
        # Read next frame
        time.sleep(0.05)             # control framerate for computation - default 20 frames per sec
        rval, frame = vc.read()

# %%
# Load facial landmark detector model
model = load_model('my_model.h5')

# Run sunglasses painter
laptop_camera_go()
